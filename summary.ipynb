# %%
from alpha_vantage.timeseries import TimeSeries
from pprint import pprint

# %%
key='8NBLCOTKI465W93V'

# %%
ts = TimeSeries(key=key, output_format='pandas')
data, meta_data = ts.get_intraday(symbol='MSFT',interval='1min', outputsize='full')
pprint(data.head(2))
# Out:
#                      1. open  2. high  3. low  4. close  5. volume
# date
# 2021-10-07 19:59:00   295.85   295.85  295.85    295.85     1501.0
# 2021-10-07 19:56:00   295.50   295.50  295.50    295.50      882.0

# %%
from alpha_vantage.sectorperformance import SectorPerformances
import matplotlib.pyplot as plt

sp = SectorPerformances(key=key, output_format='pandas')
data, meta_data = sp.get_sector()
data['Rank A: Real-Time Performance'].plot(kind='bar')
plt.title('Real Time Performance (%) per Sector')
plt.tight_layout()
plt.grid()
plt.show()

# %%
import requests
url = 'https://www.alphavantage.co/query?function=GLOBAL_QUOTE&symbol=IBM&apikey=demo'
print(url)
# Out:
# https://www.alphavantage.co/query?function=GLOBAL_QUOTE&symbol=IBM&apikey=demo

# %%
r = requests.get(url)
output = r.json()

# %%
print(output["Global Quote"]["05. price"])
# Out:
# 143.2200

# %%
import pandas as pd
from io import StringIO
url = 'https://www.alphavantage.co/query?function=EARNINGS_CALENDAR&symbol=FVRR&horizon=3month&apikey=8NBLCOTKI465W93V'
r = requests.get(url)
content = r.text
print(str(content))
# Out:
# symbol,name,reportDate,fiscalDateEnding,estimate,currency
# FVRR,Fiverr International Ltd,2021-10-26,2021-09-30,-0.01,USD

# %%
content = str(content)
f = StringIO(content)
#col_list = ["symbol"]
tbl = pd.read_csv(f, nrows=1)
#print(tbl)
#print(tbl["reportDate"][0])
print (len(tbl["reportDate"]))
if len(tbl["reportDate"]) > 0:
    dateStr = tbl["reportDate"][0]
    print(dateStr)
# Out:
# 1
# 2021-10-26

# %%
import datetime
date = datetime.datetime.strptime(dateStr, "%Y-%m-%d").date()
d = date.strftime("%b %d")
print("Output 3:", d)
# Out:
# Output 3: Oct 26

# %%
#qtrs = [[1,3],[4,6],[7,9],[10,12]]
months = 12
qtr_len = 3
qtr_no = int(months/qtr_len)
qtrs = list()
start = 0
for i in range(qtr_no):
    qtr = list()
    start = 1 + start
    end = start + 2
    qtr.append(start)
    qtr.append(end)
    qtrs.append(qtr)
    start = end

print(qtrs)
month = 10
for o in qtrs:
    #print (o)
    if month >= o[0] and month <= o[1]:
        print(o)
        break
# Out:
# [[1, 3], [4, 6], [7, 9], [10, 12]]
# [10, 12]

# %%
def get_qtrs():
    months = 12
    qtr_len = 3
    qtr_no = int(months/qtr_len)
    qtrs = list()
    start = 0
    for i in range(qtr_no):
        qtr = list()
        start = 1 + start
        end = start + 2
        qtr.append(start)
        qtr.append(end)
        qtrs.append(qtr)
        start = end
    return qtrs

# %%
def get_qtr_range(month, qtrs):
    #print(month)
    for o in qtrs:
        if month >= o[0] and month <= o[1]:
            return o

# %%
def get_stock_earningDate_detail(stock):
    url = 'https://www.alphavantage.co/query?function=EARNINGS_CALENDAR&symbol=' + stock + '&horizon=3month&apikey=8NBLCOTKI465W93V'
    try:
        r = requests.get(url)
        content = r.text
        return content
    except e:
        print(e)
        return None
    return None

# %%
import sys
from colorama import Fore, init, Back, Style
import openpyxl
import re

path = "../../Summary/stocks.xlsx"
wb_obj = openpyxl.load_workbook(path.strip())
# from the active attribute 
sheet_obj = wb_obj.active
sheet_obj
# Out:
# <Worksheet "12-Sep-2020">

# %%
max_column=sheet_obj.max_column
max_row=sheet_obj.max_row
max_column, max_row
# Out:
# (12, 58)

# %%
data = sheet_obj.cell(1,2)
print(data.value)
# Out:
# Quantity

# %%
path = "../../Summary/stocks_csv.csv"
d = pd.read_csv(path)
d["Ticker"]
# Out:
# 0        NIO
# 1        BTI
# 2       ABBV
# 3        EPD
# 4        ENB
#        ...
# 128     DGRO
# 129     TD6C
# 130     TDG0
# 131    PTTRX
# 132      NaN
# Name: Ticker, Length: 133, dtype: object

# %%
from datetime import datetime
qtrs = get_qtrs()
print(qtrs)
month = datetime.now().month
year = datetime.now().year
print(month, year)
qtr = get_qtr_range(month, qtrs)
qtr
# Out:
# [[1, 3], [4, 6], [7, 9], [10, 12]]
# 10 2021
# [10, 12]

# %%
import math
months = ["0", "JAN", "FEB", "MAR", "APR", "MAY", "JUN", "JUL", "AUG", "SEP", "OCT", "NOV", "DEC"]
print(months[qtr[0]], months[qtr[1]])
cell = months[qtr[0]]+"-"+months[qtr[1]]+" "+ str(year)
#cell = months[7]+"-"+months[9]+" "+ str(year)
print(cell)
if cell not in d:
    d[cell] = None
    d.to_csv(path, index=False)
print(d[cell][3])
#if math.isnan(d[cell][3]):
#    print("Hello")

for index, value in enumerate(d[cell]):
    #print(index, value)
    #print(type(value))
    if type(value) is str:
        print(value)
# Out:
# OCT DEC
# OCT-DEC 2021
# 26-Oct
# 15-Nov
# 28-Oct
# 26-Oct
# 04-Nov
# 26-Oct
# 25-Oct
# 27-Oct
# 17-Dec
# 27-Oct
# 03-Nov
# 27-Oct
# 09-Nov
# 30-Nov
# 01-Dec
# 26-Oct
# 08-Nov
# 03-Nov
# 01-Nov
# 26-Oct
# 08-Nov
# 06-Dec
# 27-Oct
# 19-Oct
# 03-Nov
# 03-Nov
# 25-Oct
# 10-Nov
# 29-Nov
# 30-Nov
# 03-Nov
# 27-Oct
# 27-Oct
# 10-Nov
# 17-Nov
# 02-Nov
# 08-Nov
# 08-Nov
# 26-Oct
# 26-Oct
# 01-Nov
# 08-Nov
# 02-Nov
# 27-Oct
# 03-Nov
# 10-Nov
# 16-Nov
# 10-Nov
# 08-Nov
# 26-Oct
# 06-Dec
# 01-Nov
# 02-Nov
# 27-Oct
# 15-Nov
# 02-Nov
# 25-Oct
# 02-Nov
# 01-Nov
# 10-Nov
# 16-Nov
# 30-Nov
# 08-Nov
# 01-Nov
# 03-Nov
# 03-Nov
# 11-Nov
# 19-Oct
# 14-Oct
# 27-Oct
# 01-Nov
# 07-Dec
# 26-Oct
# 09-Nov
# 26-Oct
# 08-Nov
# 08-Nov
# 21-Oct
# 08-Nov
# 08-Nov
# 08-Nov
# 18-Oct
# 03-Nov
# 03-Nov
# 27-Oct
# 26-Oct
# 16-Dec
# 16-Dec
# 29-Nov
# 03-Nov
# 27-Oct
# 27-Oct
# 08-Nov
# 08-Nov
# 08-Dec
# 03-Nov
# 16-Nov
# 02-Nov
# 13-Oct
# 25-Oct
# 26-Oct
# 08-Nov
# 15-Nov
# 18-Nov
# 19-Oct

# %%
def get_dateStr(dateStr):
    date = datetime.strptime(dateStr, "%Y-%m-%d").date()
    month = date.month
    dStr = date.strftime("%d-%b")
    return month, dStr

# %%
def get_month(dateStr):
    date = datetime.strptime(dateStr, "%Y-%m-%d").date()
    month = date.month
    #print(month)
    return month

# %%
def is_currentQtr(month):
    qtrs = get_qtrs()
    currMonth = datetime.now().month
    qtr = get_qtr_range(currMonth, qtrs)
    earningQtr = get_qtr_range(month, qtrs)
    if qtr == earningQtr:
        return True
    return False

# %%
status = is_currentQtr(7)
print(status)
# Out:
# False

# %%
from datetime import timedelta
print(d[cell][0])
content = d[cell][0]
if "(" not in content:
    print(True)
    #data = content.split(" ")
    #dateStr = (data[0].strip() + "-" + str(year))
    dateStr = (content.strip() + "-" + str(year))
    print(dateStr)
    date = datetime.strptime(dateStr, "%d-%b-%Y").date()
    nextDate = date + timedelta(days=1)
    print(str(date), str(nextDate))
    date = str(date)
    nextDate = str(nextDate)
    #month = date.month
    #dStr = date.strftime("%Y-%m-%d")
    #nStr = nextDate.strftime("%Y-%m-%d")
    #print(dStr)
    #return month, dStr
# Out:
# 15-Nov
# True
# 15-Nov-2021
# 2021-11-15 2021-11-16

# %%
url = "https://www.alphavantage.co/query?function=TIME_SERIES_DAILY_ADJUSTED&symbol=NIO&apikey=8NBLCOTKI465W93V"
r = requests.get(url)
output = r.json()

#curr = output.get("Time Series (Daily)").get('2021-04-30').get("5. adjusted close")
#prev = output.get("Time Series (Daily)").get('2021-04-29').get("5. adjusted close")
curr = output.get("Time Series (Daily)").get(nextDate).get("5. adjusted close")
prev = output.get("Time Series (Daily)").get(date).get("5. adjusted close")
print(curr, prev)
diff = float(curr) - float(prev)
print(diff)
if (diff > 0):
    print("UP")
elif (diff < 0):
    print(" - DN" + " (" + curr + ")")
else:
    print("NC")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-26-7de81c5cd5bd> in <module>
#       5 #curr = output.get("Time Series (Daily)").get('2021-04-30').get("5. adjusted close")
#       6 #prev = output.get("Time Series (Daily)").get('2021-04-29').get("5. adjusted close")
# ----> 7 curr = output.get("Time Series (Daily)").get(nextDate).get("5. adjusted close")
#       8 prev = output.get("Time Series (Daily)").get(date).get("5. adjusted close")
#       9 print(curr, prev)
#
# AttributeError: 'NoneType' object has no attribute 'get'

# %%
from datetime import datetime
from datetime import timedelta
import dateutil

def is_earningReport(title, earningDate, newsDate):
    #print(earningDate, newsDate)
    temp = earningDate
    if newsDate != temp:
        temp = temp + timedelta(days=1)
        if newsDate != temp:
            temp = earningDate
            temp = temp + timedelta(days=-1)
            if newsDate != temp:
                return False
    
    words1 = ["Announces", "Reports", "Releases", "Increase", "Raises"]
    words2 = ["Earnings", "Results", "Billable", "Revenue", "Revenues", "Income", "Letter"]
    if any(word in title for word in words1) and any(word in title for word in words2):
        #print(True)
        return True
    return False

# %%
def get_newsMarketTime(hour):
    if (hour > 12):
        return "AH"
    else:
        return "PM"

# %%
def get_newsDate(l):
    #print(l)
    interval = l.split(" ")
    num = interval[0]
    date = datetime.now()
    newsDate = None
    #print(date)
    if num == "yesterday":
        newsDate = date + timedelta(days=-1)
        newsDate = newsDate + timedelta(hours=-12.30) #For US time
    elif interval[1] == "days":
        newsDate = date + timedelta(days=-int(interval[0]))
        newsDate = newsDate + timedelta(hours=-12.30) #For US time
        #print(newsDate)
    elif interval[1] == "hours":
        newsDate = date + timedelta(hours=-int(interval[0]))
        newsDate = newsDate + timedelta(hours=-12.30) #For US time
        #print(newsDate)
    elif interval[1] == "months":
        a_month = dateutil.relativedelta.relativedelta(months=int(interval[0]))
        newsDate = date - a_month
    else:
        newsDate = date
        newsDate = newsDate + timedelta(hours=-9.30) #For US Eastern time
        #print(newsDate)
    return newsDate

# %%
def get_cell(d):
    qtrs = get_qtrs()
    #print(qtrs)
    month = datetime.now().month
    year = datetime.now().year
    #print(month, year)
    qtr = get_qtr_range(month, qtrs)
    #print(qtr)

    months = ["0", "JAN", "FEB", "MAR", "APR", "MAY", "JUN", "JUL", "AUG", "SEP", "OCT", "NOV", "DEC"]
    #print(months[qtr[0]], months[qtr[1]])
    cell = months[qtr[0]]+"-"+months[qtr[1]]+" "+ str(year)
    
    if cell not in d:
        d[cell] = None
        d.to_csv(path, index=False)
    return cell

# %%
import time
from selenium import webdriver
from bs4 import BeautifulSoup

def store_earning_news(earningDateStr, stock):
    # Web scrapper for infinite scrolling page 
    url = "https://finance.yahoo.com/quote/" + stock + "/press-releases?p=" + stock
    
    driver = webdriver.Chrome()
    driver.get(url)
    time.sleep(2)  # Allow 2 seconds for the web page to open
    scroll_pause_time = 2 
    screen_height = driver.execute_script("return window.screen.height;")   # get the screen height of the web

    i = 1
   
    SCROLL_PAUSE_TIME = 0.5
    last_height = driver.execute_script("return document.body.scrollHeight")
    while True:
        driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
        time.sleep(SCROLL_PAUSE_TIME)
        new_height = driver.execute_script("return document.body.scrollHeight")
        if new_height == last_height:
            break
        last_height = new_height

    ##### Extract Article Titles #####

    earningDate = datetime.strptime(earningDateStr, '%Y-%m-%d')
    
    news_list = list()
    soup = BeautifulSoup(driver.page_source, "html.parser")

    for t in soup.find_all(class_="Cf"):
        #print(t)
        news = dict()
        a_tag = t.find("a", class_="Fw(b)", href=True)
        #a_tag = t.find("u", class_="StretchedBox")
        if a_tag:
            #print(a_tag)
            text = a_tag.text
            news["Title"] = text
            news["Link"] = "https://finance.yahoo.com" + a_tag["href"]
            news["Provider"] = None
            news["Date"] = None
            news["Content"] = None
        
            provider = t.find("div", class_="C(#959595)")
            if provider:
                c = provider.text
                ctx = (c.encode("ascii", "replace").decode())
                l = ctx.split("?")
                news["Provider"] = l[0]
                news["Date"] = str(get_newsDate(l[1]))
            else:
                continue
        
            p_content = t.find("p", class_="Fz(14px)")
            if p_content:
                c = p_content.text
                news["Content"] = c
        
            newsDateArr = news["Date"].split(" ")
            newsDateStr = newsDateArr[0]
            newsDate = datetime.strptime(newsDateStr, '%Y-%m-%d')
            if not is_earningReport(news["Title"], earningDate, newsDate):
                continue
            else:
                news_list.append(news)
                break
    if(len(news_list) == 0):
        driver.quit()
        return False, None, None

    filename = None
    newsDateStr = None
    try:
        for news in news_list:
            print(news["Link"])
            newsDateArr = news["Date"].split(" ")
            newsTime = newsDateArr[1].replace(":", "-")
            newsDateStr = newsDateArr[0]
            #filename = stock + "-" + earningDateStr + "_" + newsTime + ".txt"
            filename = stock + "-" + newsDateStr + "_" + newsTime + ".txt"
            path = "../../Summary/unsup/"+filename
            url = news["Link"]
            driver.get(url)
            time.sleep(5)
    
            soup = BeautifulSoup(driver.page_source, "html.parser")
    
            content = soup.find("div", class_="caas-body")
    
            with open(path, 'x', encoding = 'utf-8') as f:
                if content:
                    #text = content.text
                    text = (" ".join(content.strings))
    
                    text = re.sub(r'Forward-Looking Statements.*|Forward Looking Statements.*',"",text)
                    #print(text)
                    if "Title" in news:
                        f.write(news["Title"])
                        f.write("\n")
                    f.write(text)
                else:
                    if "Title" in news:
                        f.write(news["Title"])
                        f.write("\n")
                    f.write(news["Content"])
            break
    except Exception as e:
        print(e)
        driver.quit()
        return False, None, None
                
    driver.quit()
    return True, filename, newsDateStr

# %%
from datetime import date
import glob
import holidays

def get_earningDate_quote(content, stock):
    #print(content,stock)
    if type(content) is not str:
        return None
    
    if content and "(" not in content:
        year = datetime.now().year
        dateStr = (content.strip() + "-" + str(year))
        #print(dateStr)
        try:
            ed = datetime.strptime(dateStr, "%d-%b-%Y").date()
        except:
            ed = datetime.strptime(dateStr, "%d %b-%Y").date()
        
        #print(str(ed))
        
        currDate = date.today()
        #print(currDate)
        
        if(ed>currDate):
            print("Earning for stock {} will be released later on {}".format(stock, str(ed)))
            return None
        
        #filename = "./unsup/EPD-2021-05-03*"
        filename = "../../Summary/unsup/" + stock + "-" + str(ed) + "*"

        names = glob.glob(filename)
        #print(len(names))
        quote = None
        if(len(names) > 0):
            print("Earning report for stock {} on date {} exists".format(stock, str(ed)))

            for name in glob.glob(filename):
                #print(name)
                nArr = name.split("_")
                hour = (int(nArr[1].split("-")[0]))
                break
        else:
            print("Earning report for stock {} on date {} does not exist, trying to fetch it".format(stock, str(ed)))
            res, name, newsDateStr = store_earning_news(str(ed), stock)
            print("Earning report for stock {} fetching status {}, filename {}".format(stock, res, name))
            if not res or not name:
                cd = currDate + timedelta(hours=-9.30)
                #print(str(cd))
                if(ed < cd):
                    month, quote = get_dateStr(str(cd))
                    print("Updating new earning date {} for stock {}".format(quote, stock))
                    return quote
                return None
            print("Earning report for stock {} on date {} fetched, filename {}".format(stock, newsDateStr, name))
            nArr = name.split("_")
            hour = (int(nArr[1].split("-")[0]))
        
            newsDate = datetime.strptime(newsDateStr, "%Y-%m-%d").date()
            
            if (newsDate != ed):
                ed = newsDate
                print("New Earning Date {}".format(str(ed)))
        
        month, quote = get_dateStr(str(ed))
        
        newsHour = get_newsMarketTime(hour)
        print("Earning released for stock {} {}".format(stock, newsHour))
        
        us_holidays = holidays.UnitedStates(years=year)
        if newsHour == "AH":
            nextDate = ed + timedelta(days=1)
        else:
            nextDate = ed + timedelta(days=-1)
            
        while True:
            weekno = nextDate.weekday()         
            if str(nextDate) in us_holidays:
                if newsHour == "AH":
                    nextDate = nextDate + timedelta(days=1)
                else:
                    nextDate = nextDate + timedelta(days=-1)
                continue
            elif weekno >= 5:
                if newsHour == "AH":
                    nextDate = nextDate + timedelta(days=1)
                else:
                    nextDate = nextDate + timedelta(days=-1)
                continue
            else:
                break
        
        print("Get price diff for stock {} from date {} and date {}".format(stock, str(ed), str(nextDate)))
        
        ed = str(ed)
        nextDate = str(nextDate)
        
        retry = 0
        output = None
        #quote = None
        while(retry < 2):
            try:
                url = "https://www.alphavantage.co/query?function=TIME_SERIES_DAILY_ADJUSTED&symbol="+stock+"&apikey=8NBLCOTKI465W93V"
                r = requests.get(url)
                output = r.json()
                break
            except e:
                print(e)
                retry = retry + 1
                time.sleep(5)
        if not output:
            return quote
        
        curr = output.get("Time Series (Daily)")
        if curr is None:
            return quote
        curr = curr.get(nextDate)
        if curr is None:
            return quote
        curr = curr.get("5. adjusted close")
        if curr is None:
            return quote
        
        prev = output.get("Time Series (Daily)")
        if prev is None:
            return quote
        prev = prev.get(ed)
        if prev is None:
            return quote
        prev = prev.get("5. adjusted close")
        if prev is None:
            return quote
        
        #print(curr, prev)
        if not quote:
            return quote
        
        if newsHour == "AH":
            diff = float(curr) - float(prev)
        else:
            diff = float(prev) - float(curr)
        #print(diff)
        if (diff > 0):
            if newsHour == "AH":
                quote = quote + (" - UP" + " (" + curr + ")")
            else:
                quote = quote + (" - UP" + " (" + prev + ")")
        elif (diff < 0):
            if newsHour == "AH":
                quote = quote + (" - DN" + " (" + curr + ")")
            else:
                quote = quote + (" - DN" + " (" + prev + ")")
        else:
            if newsHour == "AH":
                quote = quote + (" - NC" + " (" + curr + ")")
            else:
                quote = quote + (" - DN" + " (" + prev + ")")
        #print(quote)
        return (quote)
    
    return None

# %%
path = "../../Summary/stocks_csv.csv"
d = pd.read_csv(path)
quote = get_earningDate_quote(d[cell][75], d["Ticker"][75])
print(quote)
# Out:
# Earning for stock NVDA will be released later on 2021-11-16
# None

# %%
import time

def update_stock_earningDate(d, path, phase=1, updateAll=True):
    RETRY_COUNT = 3
    others = ["SCHB", "SCHD", "SCHA", "SRET", "SCHK", "DGRO", "DBEU", "TD6C", "TDG0", "PTTRX"]

    retry = 0
    status = True
    #pending_stocks = []
    
    stocks = d["Ticker"]
    #print(stocks)
    if(len(stocks) == 0):
        return True
    
    cell = get_cell(d)
    if not cell:
        return True
    
    for index, stock in enumerate(stocks):
        retry = 0
        earningDate = d[cell][index]
        
        if phase==2:
            if type(earningDate) is not str:
                #print("Earning date for stock {} not available".format(stock))
                continue
            quote = get_earningDate_quote(earningDate, stock)
            if quote is not None:
                print("Update Stock {} with quote {}".format(stock, quote))
                d.loc[index, cell] = (quote)
                d.to_csv(path, index=False)
            else:
                if "(" in earningDate:
                    print("Quote for stock {} on earning date {} already generated".format(stock, earningDate))
                else:
                    print("Quote for stock {} on earning date {} not generated yet".format(stock, earningDate))
            continue
        
        if phase==1:
            if type(earningDate) is str and not updateAll:
                continue
                        
            if type(earningDate) is str:
                if "(" in earningDate:
                    continue
        
        if stock in others:
            #print(stock, None)
            continue
        if type(stock) is not str:
            continue
        while(retry <= RETRY_COUNT):
            content = get_stock_earningDate_detail(stock)
            if content:
                content = str(content)
                f = StringIO(content)
                tbl = pd.read_csv(f, nrows=1)
                if "reportDate" in tbl and len(tbl["reportDate"]) > 0:
                    dateStr = tbl["reportDate"][0]
                    month, dateStr = get_dateStr(dateStr)
                    status1 = is_currentQtr(month)
                    print(stock, month, dateStr, status1)
                    if not status1:
                        #print(stock,dateStr)
                        break
                    d.loc[index, cell] = str(dateStr)
                    d.to_csv(path, index=False)
                    time.sleep(5)
                    break
                elif "reportDate" not in tbl:
                    retry = retry + 1
                    if(retry > RETRY_COUNT):
                        print(stock, None)
                        #pending_stocks.append(stock)
                        status = False
                    time.sleep(5)
                    continue
                else:
                    print(stock, None)
                    #pending_stocks.append(stock)
                    status = False
                    time.sleep(5)
                    break
    return status

# %%
status = False
retry = 0
path = "../../Summary/stocks_csv.csv"
d = pd.read_csv(path)

while(retry < 2):
    if retry == 0:
        status = update_stock_earningDate(d, path, 1, True)
    else:
        status = update_stock_earningDate(d, path, 1, False)
    print(status, retry)
    if(status):
        break
    else:
        retry = retry + 1

print(d[cell])
# Out:
# NIO 11 15-Nov True
# BTI None
# ABBV 10 28-Oct True
# EPD 10 26-Oct True
# ENB 11 04-Nov True
# V 10 26-Oct True
# MSFT 10 25-Oct True
# KNSL 10 27-Oct True
# NKE 12 17-Dec True
# BMY 10 27-Oct True
# ADYEY None
# APPN None
# TEAM 10 27-Oct True
# CGC 11 09-Nov True
# CRWD 11 30-Nov True
# DOCU 12 01-Dec True
# FVRR 10 26-Oct True
# FLGT 11 08-Nov True
# HZNP None
# JD None
# PYPL 11 01-Nov True
# PINS 10 26-Oct True
# RNG 11 08-Nov True
# SFIX 12 06-Dec True
# STNE None
# TSLA 10 19-Oct True
# TTD 11 03-Nov True
# RGEN 11 03-Nov True
# TWLO 10 25-Oct True
# DIS 11 10-Nov True
# ZM None
# ZS 11 30-Nov True
# ASML None
# NVTA 11 03-Nov True
# SHOP 10 27-Oct True
# VRTX 10 27-Oct True
# WIX None
# INTU 11 17-Nov True
# MELI 11 02-Nov True
# MGNI 11 08-Nov True
# PSEC 11 08-Nov True
# TDOC 10 26-Oct True
# CRSP None
# PACB 11 01-Nov True
# LMND 11 08-Nov True
# PAYC 11 02-Nov True
# WD 10 27-Oct True
# PTON 11 03-Nov True
# QS None
# INMD 11 10-Nov True
# RIO None
# SKLZ 11 16-Nov True
# COIN None
# BFLY None
# CPNG None
# XPEV 11 10-Nov True
# EXPI 11 08-Nov True
# FSR 10 26-Oct True
# GME 12 06-Dec True
# AMC 11 01-Nov True
# OPEN None
# IIPR 11 02-Nov True
# BIO 10 27-Oct True
# CSPR 11 15-Nov True
# MTCH 11 02-Nov True
# MSCI 10 25-Oct True
# QRVO None
# MED 11 01-Nov True
# PLTR 11 10-Nov True
# NVDA 11 16-Nov True
# UPST None
# DOCN None
# SNOW 11 30-Nov True
# NNOX None
# WW None
# ANET 11 01-Nov True
# HUBS 11 03-Nov True
# SQ 11 03-Nov True
# DKNG 11 11-Nov True
# MPNGF None
# NEE 10 19-Oct True
# DPZ 10 14-Oct True
# FB 10 27-Oct True
# OKTA 11 01-Nov True
# RH 12 07-Dec True
# YNDX None
# RVLV 11 09-Nov True
# ETSY 10 26-Oct True
# VIR 11 08-Nov True
# FTCH 11 08-Nov True
# CMG 10 21-Oct True
# ACB None
# JMIA 11 08-Nov True
# BYND 11 08-Nov True
# SNAP 10 18-Oct True
# UBER 11 03-Nov True
# ROKU 11 03-Nov True
# AAPL None
# NOW 10 26-Oct True
# ADBE 12 16-Dec True
# FDX 12 16-Dec True
# CRM 11 29-Nov True
# GOOG None
# BABA 11 03-Nov True
# MCD 10 27-Oct True
# AMZN 10 27-Oct True
# CFLT None
# PLUG 11 08-Nov True
# ZNGA None
# LULU 12 08-Dec True
# NET 11 03-Nov True
# INVZ None
# BILI 11 16-Nov True
# IDXX 11 02-Nov True
# JPM None
# DXCM 10 25-Oct True
# COF 10 26-Oct True
# FUBO 11 08-Nov True
# PANW 11 15-Nov True
# AMAT 11 18-Nov True
# ISRG 10 19-Oct True
# BP None
# False 0
# BTI None
# ADYEY None
# JD None
# ASML None
# QS None
# RIO None
# COIN None
# BFLY None
# CPNG None
# OPEN None
# QRVO 11 02-Nov True
# UPST None
# DOCN None
# WW None
# MPNGF None
# GOOG None
# CFLT None
# INVZ None
# BP None
# False 1
# 0      15-Nov
# 1         NaN
# 2      28-Oct
# 3      26-Oct
# 4      04-Nov
#         ...
# 128       NaN
# 129       NaN
# 130       NaN
# 131       NaN
# 132       NaN
# Name: OCT-DEC 2021, Length: 133, dtype: object

# %%
path = "../../Summary/stocks_csv.csv"
d = pd.read_csv(path)

status = update_stock_earningDate(d, path, 2)
print(status)
# Out:
# Earning for stock NIO will be released later on 2021-11-15
# Quote for stock NIO on earning date 15-Nov not generated yet
# Earning for stock ABBV will be released later on 2021-10-28
# Quote for stock ABBV on earning date 28-Oct not generated yet
# Earning for stock EPD will be released later on 2021-10-26
# Quote for stock EPD on earning date 26-Oct not generated yet
# Earning for stock ENB will be released later on 2021-11-04
# Quote for stock ENB on earning date 04-Nov not generated yet
# Earning for stock V will be released later on 2021-10-26
# Quote for stock V on earning date 26-Oct not generated yet
# Earning for stock MSFT will be released later on 2021-10-25
# Quote for stock MSFT on earning date 25-Oct not generated yet
# Earning for stock KNSL will be released later on 2021-10-27
# Quote for stock KNSL on earning date 27-Oct not generated yet
# Earning for stock NKE will be released later on 2021-12-17
# Quote for stock NKE on earning date 17-Dec not generated yet
# Earning for stock BMY will be released later on 2021-10-27
# Quote for stock BMY on earning date 27-Oct not generated yet
# Earning for stock APPN will be released later on 2021-11-03
# Quote for stock APPN on earning date 03-Nov not generated yet
# Earning for stock TEAM will be released later on 2021-10-27
# Quote for stock TEAM on earning date 27-Oct not generated yet
# Earning for stock CGC will be released later on 2021-11-09
# Quote for stock CGC on earning date 09-Nov not generated yet
# Earning for stock CRWD will be released later on 2021-11-30
# Quote for stock CRWD on earning date 30-Nov not generated yet
# Earning for stock DOCU will be released later on 2021-12-01
# Quote for stock DOCU on earning date 01-Dec not generated yet
# Earning for stock FVRR will be released later on 2021-10-26
# Quote for stock FVRR on earning date 26-Oct not generated yet
# Earning for stock FLGT will be released later on 2021-11-08
# Quote for stock FLGT on earning date 08-Nov not generated yet
# Earning for stock HZNP will be released later on 2021-11-03
# Quote for stock HZNP on earning date 03-Nov not generated yet
# Earning for stock PYPL will be released later on 2021-11-01
# Quote for stock PYPL on earning date 01-Nov not generated yet
# Earning for stock PINS will be released later on 2021-10-26
# Quote for stock PINS on earning date 26-Oct not generated yet
# Earning for stock RNG will be released later on 2021-11-08
# Quote for stock RNG on earning date 08-Nov not generated yet
# Earning for stock SFIX will be released later on 2021-12-06
# Quote for stock SFIX on earning date 06-Dec not generated yet
# Earning for stock STNE will be released later on 2021-10-27
# Quote for stock STNE on earning date 27-Oct not generated yet
# Earning for stock TSLA will be released later on 2021-10-19
# Quote for stock TSLA on earning date 19-Oct not generated yet
# Earning for stock TTD will be released later on 2021-11-03
# Quote for stock TTD on earning date 03-Nov not generated yet
# Earning for stock RGEN will be released later on 2021-11-03
# Quote for stock RGEN on earning date 03-Nov not generated yet
# Earning for stock TWLO will be released later on 2021-10-25
# Quote for stock TWLO on earning date 25-Oct not generated yet
# Earning for stock DIS will be released later on 2021-11-10
# Quote for stock DIS on earning date 10-Nov not generated yet
# Earning for stock ZM will be released later on 2021-11-29
# Quote for stock ZM on earning date 29-Nov not generated yet
# Earning for stock ZS will be released later on 2021-11-30
# Quote for stock ZS on earning date 30-Nov not generated yet
# Earning for stock NVTA will be released later on 2021-11-03
# Quote for stock NVTA on earning date 03-Nov not generated yet
# Earning for stock SHOP will be released later on 2021-10-27
# Quote for stock SHOP on earning date 27-Oct not generated yet
# Earning for stock VRTX will be released later on 2021-10-27
# Quote for stock VRTX on earning date 27-Oct not generated yet
# Earning for stock WIX will be released later on 2021-11-10
# Quote for stock WIX on earning date 10-Nov not generated yet
# Earning for stock INTU will be released later on 2021-11-17
# Quote for stock INTU on earning date 17-Nov not generated yet
# Earning for stock MELI will be released later on 2021-11-02
# Quote for stock MELI on earning date 02-Nov not generated yet
# Earning for stock MGNI will be released later on 2021-11-08
# Quote for stock MGNI on earning date 08-Nov not generated yet
# Earning for stock PSEC will be released later on 2021-11-08
# Quote for stock PSEC on earning date 08-Nov not generated yet
# Earning for stock TDOC will be released later on 2021-10-26
# Quote for stock TDOC on earning date 26-Oct not generated yet
# Earning for stock CRSP will be released later on 2021-10-26
# Quote for stock CRSP on earning date 26-Oct not generated yet
# Earning for stock PACB will be released later on 2021-11-01
# Quote for stock PACB on earning date 01-Nov not generated yet
# Earning for stock LMND will be released later on 2021-11-08
# Quote for stock LMND on earning date 08-Nov not generated yet
# Earning for stock PAYC will be released later on 2021-11-02
# Quote for stock PAYC on earning date 02-Nov not generated yet
# Earning for stock WD will be released later on 2021-10-27
# Quote for stock WD on earning date 27-Oct not generated yet
# Earning for stock PTON will be released later on 2021-11-03
# Quote for stock PTON on earning date 03-Nov not generated yet
# Earning for stock INMD will be released later on 2021-11-10
# Quote for stock INMD on earning date 10-Nov not generated yet
# Earning for stock SKLZ will be released later on 2021-11-16
# Quote for stock SKLZ on earning date 16-Nov not generated yet
# Earning for stock XPEV will be released later on 2021-11-10
# Quote for stock XPEV on earning date 10-Nov not generated yet
# Earning for stock EXPI will be released later on 2021-11-08
# Quote for stock EXPI on earning date 08-Nov not generated yet
# Earning for stock FSR will be released later on 2021-10-26
# Quote for stock FSR on earning date 26-Oct not generated yet
# Earning for stock GME will be released later on 2021-12-06
# Quote for stock GME on earning date 06-Dec not generated yet
# Earning for stock AMC will be released later on 2021-11-01
# Quote for stock AMC on earning date 01-Nov not generated yet
# Earning for stock IIPR will be released later on 2021-11-02
# Quote for stock IIPR on earning date 02-Nov not generated yet
# Earning for stock BIO will be released later on 2021-10-27
# Quote for stock BIO on earning date 27-Oct not generated yet
# Earning for stock CSPR will be released later on 2021-11-15
# Quote for stock CSPR on earning date 15-Nov not generated yet
# Earning for stock MTCH will be released later on 2021-11-02
# Quote for stock MTCH on earning date 02-Nov not generated yet
# Earning for stock MSCI will be released later on 2021-10-25
# Quote for stock MSCI on earning date 25-Oct not generated yet
# Earning for stock QRVO will be released later on 2021-11-02
# Quote for stock QRVO on earning date 02-Nov not generated yet
# Earning for stock MED will be released later on 2021-11-01
# Quote for stock MED on earning date 01-Nov not generated yet
# Earning for stock PLTR will be released later on 2021-11-10
# Quote for stock PLTR on earning date 10-Nov not generated yet
# Earning for stock NVDA will be released later on 2021-11-16
# Quote for stock NVDA on earning date 16-Nov not generated yet
# Earning for stock SNOW will be released later on 2021-11-30
# Quote for stock SNOW on earning date 30-Nov not generated yet
# Earning for stock NNOX will be released later on 2021-11-08
# Quote for stock NNOX on earning date 08-Nov not generated yet
# Earning for stock ANET will be released later on 2021-11-01
# Quote for stock ANET on earning date 01-Nov not generated yet
# Earning for stock HUBS will be released later on 2021-11-03
# Quote for stock HUBS on earning date 03-Nov not generated yet
# Earning for stock SQ will be released later on 2021-11-03
# Quote for stock SQ on earning date 03-Nov not generated yet
# Earning for stock DKNG will be released later on 2021-11-11
# Quote for stock DKNG on earning date 11-Nov not generated yet
# Earning for stock NEE will be released later on 2021-10-19
# Quote for stock NEE on earning date 19-Oct not generated yet
# Earning for stock DPZ will be released later on 2021-10-14
# Quote for stock DPZ on earning date 14-Oct not generated yet
# Earning for stock FB will be released later on 2021-10-27
# Quote for stock FB on earning date 27-Oct not generated yet
# Earning for stock OKTA will be released later on 2021-11-01
# Quote for stock OKTA on earning date 01-Nov not generated yet
# Earning for stock RH will be released later on 2021-12-07
# Quote for stock RH on earning date 07-Dec not generated yet
# Earning for stock YNDX will be released later on 2021-10-26
# Quote for stock YNDX on earning date 26-Oct not generated yet
# Earning for stock RVLV will be released later on 2021-11-09
# Quote for stock RVLV on earning date 09-Nov not generated yet
# Earning for stock ETSY will be released later on 2021-10-26
# Quote for stock ETSY on earning date 26-Oct not generated yet
# Earning for stock VIR will be released later on 2021-11-08
# Quote for stock VIR on earning date 08-Nov not generated yet
# Earning for stock FTCH will be released later on 2021-11-08
# Quote for stock FTCH on earning date 08-Nov not generated yet
# Earning for stock CMG will be released later on 2021-10-21
# Quote for stock CMG on earning date 21-Oct not generated yet
# Earning for stock ACB will be released later on 2021-11-08
# Quote for stock ACB on earning date 08-Nov not generated yet
# Earning for stock JMIA will be released later on 2021-11-08
# Quote for stock JMIA on earning date 08-Nov not generated yet
# Earning for stock BYND will be released later on 2021-11-08
# Quote for stock BYND on earning date 08-Nov not generated yet
# Earning for stock SNAP will be released later on 2021-10-18
# Quote for stock SNAP on earning date 18-Oct not generated yet
# Earning for stock UBER will be released later on 2021-11-03
# Quote for stock UBER on earning date 03-Nov not generated yet
# Earning for stock ROKU will be released later on 2021-11-03
# Quote for stock ROKU on earning date 03-Nov not generated yet
# Earning for stock AAPL will be released later on 2021-10-27
# Quote for stock AAPL on earning date 27-Oct not generated yet
# Earning for stock NOW will be released later on 2021-10-26
# Quote for stock NOW on earning date 26-Oct not generated yet
# Earning for stock ADBE will be released later on 2021-12-16
# Quote for stock ADBE on earning date 16-Dec not generated yet
# Earning for stock FDX will be released later on 2021-12-16
# Quote for stock FDX on earning date 16-Dec not generated yet
# Earning for stock CRM will be released later on 2021-11-29
# Quote for stock CRM on earning date 29-Nov not generated yet
# Earning for stock BABA will be released later on 2021-11-03
# Quote for stock BABA on earning date 03-Nov not generated yet
# Earning for stock MCD will be released later on 2021-10-27
# Quote for stock MCD on earning date 27-Oct not generated yet
# Earning for stock AMZN will be released later on 2021-10-27
# Quote for stock AMZN on earning date 27-Oct not generated yet
# Earning for stock PLUG will be released later on 2021-11-08
# Quote for stock PLUG on earning date 08-Nov not generated yet
# Earning for stock ZNGA will be released later on 2021-11-08
# Quote for stock ZNGA on earning date 08-Nov not generated yet
# Earning for stock LULU will be released later on 2021-12-08
# Quote for stock LULU on earning date 08-Dec not generated yet
# Earning for stock NET will be released later on 2021-11-03
# Quote for stock NET on earning date 03-Nov not generated yet
# Earning for stock BILI will be released later on 2021-11-16
# Quote for stock BILI on earning date 16-Nov not generated yet
# Earning for stock IDXX will be released later on 2021-11-02
# Quote for stock IDXX on earning date 02-Nov not generated yet
# Earning for stock JPM will be released later on 2021-10-13
# Quote for stock JPM on earning date 13-Oct not generated yet
# Earning for stock DXCM will be released later on 2021-10-25
# Quote for stock DXCM on earning date 25-Oct not generated yet
# Earning for stock COF will be released later on 2021-10-26
# Quote for stock COF on earning date 26-Oct not generated yet
# Earning for stock FUBO will be released later on 2021-11-08
# Quote for stock FUBO on earning date 08-Nov not generated yet
# Earning for stock PANW will be released later on 2021-11-15
# Quote for stock PANW on earning date 15-Nov not generated yet
# Earning for stock AMAT will be released later on 2021-11-18
# Quote for stock AMAT on earning date 18-Nov not generated yet
# Earning for stock ISRG will be released later on 2021-10-19
# Quote for stock ISRG on earning date 19-Oct not generated yet
# True

# %%
def get_earningDates(d, when):
    dt = datetime.today()
    stocks = d["Ticker"]
    
    cell = get_cell(d)
    if not cell:
        return None
    
    if(when == "WK"):
        start = dt - timedelta(days=dt.weekday())
        end = start + timedelta(days=6)
    elif (when == "TD"):
        start = dt
        end = start
    elif (when == "TM"):
        start = dt + timedelta(days=1)
        end = start
    elif (when == "YT"):
        start = dt - timedelta(days=1)
        end = start
    else:
        return None

    start = datetime.date(start)
    end = datetime.date(end)
    #print(start)
    #print(end)

    year = dt.year

    result = []
    for index, stock in enumerate(stocks):
        eStr = d[cell][index]
        combo = []
        
        if type(eStr) is not str:
            continue
            
        if "(" in eStr:
            eStr = eStr.split("-")
            #print(eStr)
            dateStr = (eStr[0].strip() + "-" + eStr[1].strip() + "-" + str(year))
        else:
            dateStr = (eStr.strip() + "-" + str(year))

        #print(dateStr)
        try:
            ed = datetime.strptime(dateStr, "%d-%b-%Y").date()
        except:
            ed = datetime.strptime(dateStr, "%d %b-%Y").date()
        #print(ed)

        if ed >= start and ed <= end:
            #print(stock, start, end, ed, True)
            combo.append(stock)
            combo.append(dateStr)
            result.append(combo)
            
    return result

# %%
stocks = get_earningDates(d, "WK")
print(stocks, "\n", len(stocks))
# Out:
# []
#  0

# %%
import re
import time
from selenium import webdriver
from bs4 import BeautifulSoup
import spacy

#nlp = spacy.load("en_core_web_trf")

url = "https://finance.yahoo.com/news/aurora-cannabis-announces-fiscal-2021-201500266.html"
print(url)

driver = webdriver.Chrome()

driver.get(url)
time.sleep(2)

soup = BeautifulSoup(driver.page_source, "html.parser")
    
content = soup.find("div", class_="caas-body")
#print(content)

if content:
    #print(content.get_text())
    #filename = "PANW-2021-05-20_16-52-59.518356.txt"
    #path = "./unsupnew/"+filename
    output = (" ".join(content.strings))
    
    output = re.sub(r'Forward-Looking Statements.*|Forward Looking Statements.*',"",output)
    
    print(output)
    
    #with open(path, 'x', encoding = 'utf-8') as f:
    #    f.write(output)
    #soup = BeautifulSoup(content, "html.parser")
    #soup.get_text(separator="\n")
    #print(content.text)
    #doc = nlp(output)
    #sentences = [str(sent).strip() for sent in doc.sents]
    #print(len(sentences))
    #print(sentences)
    
    #for line in sentences:
    #    print("****** {}".format(line))
        
driver.quit()

# %%
import os
import re
import time
from selenium import webdriver
from bs4 import BeautifulSoup
import spacy

files_link = [
              "https://finance.yahoo.com/news/aurora-cannabis-announces-fiscal-2021-201500266.html",
              "https://finance.yahoo.com/news/applied-materials-announces-second-quarter-200100432.html",
              "https://finance.yahoo.com/news/arista-networks-inc-reports-first-200500732.html",
              "https://finance.yahoo.com/news/appian-announces-first-quarter-2021-200100501.html",
              "https://finance.yahoo.com/news/alibaba-group-announces-march-quarter-112200701.html",
              "https://finance.yahoo.com/news/bristol-myers-squibb-reports-first-105900221.html",
              "https://finance.yahoo.com/news/beyond-meat-reports-first-quarter-200500876.html",
              "https://finance.yahoo.com/news/casper-reports-first-quarter-2021-103000149.html",
              "https://finance.yahoo.com/news/walt-disney-company-reports-second-200500011.html",
              "https://finance.yahoo.com/news/draftkings-reports-first-quarter-2021-110000293.html",
              "https://finance.yahoo.com/news/enbridge-reports-strong-first-quarter-110000848.html",
              "https://finance.yahoo.com/news/enterprise-reports-first-quarter-2021-100000525.html",
              "https://finance.yahoo.com/news/etsy-inc-reports-first-quarter-200500590.html",
              "https://finance.yahoo.com/news/exp-world-holdings-reports-record-123000146.html",
              "https://finance.yahoo.com/news/fulgent-genetics-reports-record-first-200500258.html",
              "https://finance.yahoo.com/news/farfetch-announces-first-quarter-2021-200600856.html",
              "https://finance.yahoo.com/news/fiverr-announces-first-quarter-2021-050000648.html",
              "https://finance.yahoo.com/news/hubspot-reports-q1-2021-results-201000012.html",
              "https://finance.yahoo.com/news/havertys-reports-first-quarter-2021-204000308.html",
              "https://finance.yahoo.com/news/horizon-therapeutics-plc-reports-first-110000158.html",
              "https://finance.yahoo.com/news/innovative-industrial-properties-reports-first-200600167.html",
              "https://finance.yahoo.com/news/inmode-reports-first-quarter-2021-111500734.html",
              "https://finance.yahoo.com/news/jd-com-announces-first-quarter-105300974.html",
              "https://finance.yahoo.com/news/lemonade-announces-first-quarter-2021-210000181.html",
              "https://finance.yahoo.com/news/medifast-inc-announces-first-quarter-200500463.html",
              "https://finance.yahoo.com/news/mercadolibre-inc-reports-first-quarter-213000148.html",
              "https://finance.yahoo.com/news/magnite-reports-first-quarter-2021-200500357.html",
              "https://finance.yahoo.com/news/match-group-reports-first-quarter-201100924.html",
              "https://finance.yahoo.com/news/nanox-announces-first-quarter-2021-110000907.html",
              "https://finance.yahoo.com/news/invitae-reports-103-6-million-200500995.html",
              "https://finance.yahoo.com/news/palo-alto-networks-reports-fiscal-200500317.html",
              "https://finance.yahoo.com/news/paycom-software-inc-reports-first-200500900.html",
              "https://finance.yahoo.com/news/palantir-reports-49-revenue-growth-110000817.html",
              "https://finance.yahoo.com/news/prospect-capital-releases-march-2021-203600447.html",
              "https://finance.yahoo.com/news/paypal-reports-first-quarter-2021-201600784.html",
              "https://finance.yahoo.com/news/qorvo-announces-fiscal-2021-fourth-200000135.html",
              "https://finance.yahoo.com/news/quantumscape-announces-first-quarter-2021-201500516.html",
              "https://finance.yahoo.com/news/repligen-reports-first-quarter-2021-113000798.html",
              "https://finance.yahoo.com/news/ringcentral-announces-first-quarter-2021-200600324.html",
              "https://finance.yahoo.com/news/roku-releases-first-quarter-2021-200300047.html",
              "https://finance.yahoo.com/news/revolve-group-announces-first-quarter-200500204.html",
              "https://finance.yahoo.com/news/square-inc-announces-first-quarter-200600101.html",
              "https://finance.yahoo.com/news/trade-desk-reports-first-quarter-123000864.html",
              "https://finance.yahoo.com/news/twilio-announces-first-quarter-2021-201000982.html",
              "https://finance.yahoo.com/news/uber-announces-results-first-quarter-200500302.html",
              "https://finance.yahoo.com/news/vir-biotechnology-provides-corporate-reports-200500093.html",
              "https://finance.yahoo.com/news/walker-dunlop-reports-20-growth-100000820.html",
              "https://finance.yahoo.com/news/wix-reports-first-quarter-2021-050000836.html",
              "https://finance.yahoo.com/news/ww-announces-first-quarter-2021-200100511.html",
              "https://finance.yahoo.com/news/zynga-announces-first-quarter-2021-200500864.html",
             ]

skip_list = ["AAPL", "ABBV", "CMG", "ASML", "ISRG", "INTC", "LRCX", 
             "KNSL", "LRN", "NIO", "MSFT", "NOW", "PACB", "PINS", "SHOP", "SIVB", "SNAP", 
             "TDOC", "TEAM", "TSLA", "V", "VRTX", "PTON"]
print(len(files_link), len(skip_list))

path = "../../Summary/unsup"
newpath = "../../Summary/unsupnew/"


cnt = 0
for fname in os.listdir(path):
    #print(fname)
    nf = os.path.join(newpath, fname)
    words = fname.split("-")
    stock = words[0]
    print(stock, nf, files_link[cnt])
    driver = webdriver.Chrome()    
    
    url = files_link[cnt]
    #print(url)

    driver.get(url)
    time.sleep(3)

    soup = BeautifulSoup(driver.page_source, "html.parser")
    
    content = soup.find("div", class_="caas-body")
    
    if content:
    
        output = (" ".join(content.strings))
    
        output = re.sub(r'Forward-Looking Statements.*|Forward Looking Statements.*',"",output)
    
        #print(output)
    
        with open(nf, 'x', encoding = 'utf-8') as f:
            f.write(output)
    
    driver.quit()
    cnt = cnt + 1
    
print(cnt)
# Out:
# 50 23
# ACB ./unsupnew/ACB-2021-05-13_16-52-59.518356.txt https://finance.yahoo.com/news/aurora-cannabis-announces-fiscal-2021-201500266.html
# AMAT ./unsupnew/AMAT-2021-05-20_13-28-46.962705.txt https://finance.yahoo.com/news/applied-materials-announces-second-quarter-200100432.html
# ANET ./unsupnew/ANET-2021-05-04_16-29-14.279301.txt https://finance.yahoo.com/news/arista-networks-inc-reports-first-200500732.html
# APPN ./unsupnew/APPN-2021-05-06_13-01-52.344079.txt https://finance.yahoo.com/news/appian-announces-first-quarter-2021-200100501.html
# BABA ./unsupnew/BABA-2021-05-13_07-54-38.989614.txt https://finance.yahoo.com/news/alibaba-group-announces-march-quarter-112200701.html
# BMY ./unsupnew/BMY-2021-04-29_14-18-33.950906.txt https://finance.yahoo.com/news/bristol-myers-squibb-reports-first-105900221.html
# BYND ./unsupnew/BYND-2021-05-06_13-06-00.598192.txt https://finance.yahoo.com/news/beyond-meat-reports-first-quarter-200500876.html
# CSPR ./unsupnew/CSPR-2021-05-13_07-52-27.895874.txt https://finance.yahoo.com/news/casper-reports-first-quarter-2021-103000149.html
# DIS ./unsupnew/DIS-2021-05-13_16-51-45.902813.txt https://finance.yahoo.com/news/walt-disney-company-reports-second-200500011.html
# DKNG ./unsupnew/DKNG-2021-05-07_04-05-50.618795.txt https://finance.yahoo.com/news/draftkings-reports-first-quarter-2021-110000293.html
# ENB ./unsupnew/ENB-2021-05-07_04-05-25.621128.txt https://finance.yahoo.com/news/enbridge-reports-strong-first-quarter-110000848.html
# EPD ./unsupnew/EPD-2021-05-03_09-36-49.726321.txt https://finance.yahoo.com/news/enterprise-reports-first-quarter-2021-100000525.html
# ETSY ./unsupnew/ETSY-2021-05-05_16-29-57.742441.txt https://finance.yahoo.com/news/etsy-inc-reports-first-quarter-200500590.html
# EXPI ./unsupnew/EXPI-2021-05-06_10-12-26.442713.txt https://finance.yahoo.com/news/exp-world-holdings-reports-record-123000146.html
# FLGT ./unsupnew/FLGT-2021-05-06_13-02-31.919142.txt https://finance.yahoo.com/news/fulgent-genetics-reports-record-first-200500258.html
# FTCH ./unsupnew/FTCH-2021-05-13_16-52-34.953400.txt https://finance.yahoo.com/news/farfetch-announces-first-quarter-2021-200600856.html
# FVRR ./unsupnew/FVRR-2021-05-06_01-27-44.328541.txt https://finance.yahoo.com/news/fiverr-announces-first-quarter-2021-050000648.html
# HUBS ./unsupnew/HUBS-2021-05-05_16-28-54.059893.txt https://finance.yahoo.com/news/hubspot-reports-q1-2021-results-201000012.html
# HVT ./unsupnew/HVT-2021-04-28_14-12-56.515804.txt https://finance.yahoo.com/news/havertys-reports-first-quarter-2021-204000308.html
# HZNP ./unsupnew/HZNP-2021-05-05_07-19-59.020314.txt https://finance.yahoo.com/news/horizon-therapeutics-plc-reports-first-110000158.html
# IIPR ./unsupnew/IIPR-2021-05-05_16-26-47.724753.txt https://finance.yahoo.com/news/innovative-industrial-properties-reports-first-200600167.html
# INMD ./unsupnew/INMD-2021-05-05_07-21-00.938193.txt https://finance.yahoo.com/news/inmode-reports-first-quarter-2021-111500734.html
# JD ./unsupnew/JD-2021-05-19_03-45-09.453287.txt https://finance.yahoo.com/news/jd-com-announces-first-quarter-105300974.html
# LMND ./unsupnew/LMND-2021-05-11_14-33-42.126588.txt https://finance.yahoo.com/news/lemonade-announces-first-quarter-2021-210000181.html
# MED ./unsupnew/MED-2021-05-05_10-11-10.507491.txt https://finance.yahoo.com/news/medifast-inc-announces-first-quarter-200500463.html
# MELI ./unsupnew/MELI-2021-05-05_17-28-18.105927.txt https://finance.yahoo.com/news/mercadolibre-inc-reports-first-quarter-213000148.html
# MGNI ./unsupnew/MGNI-2021-05-10_16-24-58.943758.txt https://finance.yahoo.com/news/magnite-reports-first-quarter-2021-200500357.html
# MTCH ./unsupnew/MTCH-2021-05-04_16-27-42.581085.txt https://finance.yahoo.com/news/match-group-reports-first-quarter-201100924.html
# NNOX ./unsupnew/NNOX-2021-05-11_04-17-23.679952.txt https://finance.yahoo.com/news/nanox-announces-first-quarter-2021-110000907.html
# NVTA ./unsupnew/NVTA-2021-05-04_16-35-57.895245.txt https://finance.yahoo.com/news/invitae-reports-103-6-million-200500995.html
# PANW ./unsupnew/PANW-2021-05-20_13-27-50.942982.txt https://finance.yahoo.com/news/palo-alto-networks-reports-fiscal-200500317.html
# PAYC ./unsupnew/PAYC-2021-05-04_16-26-42.222919.txt https://finance.yahoo.com/news/paycom-software-inc-reports-first-200500900.html
# PLTR ./unsupnew/PLTR-2021-05-11_07-05-18.413191.txt https://finance.yahoo.com/news/palantir-reports-49-revenue-growth-110000817.html
# PSEC ./unsupnew/PSEC-2021-05-10_09-01-24.596065.txt https://finance.yahoo.com/news/prospect-capital-releases-march-2021-203600447.html
# PYPL ./unsupnew/PYPL-2021-05-05_16-38-00.930671.txt https://finance.yahoo.com/news/paypal-reports-first-quarter-2021-201600784.html
# QRVO ./unsupnew/QRVO-2021-05-05_16-27-14.278424.txt https://finance.yahoo.com/news/qorvo-announces-fiscal-2021-fourth-200000135.html
# QS ./unsupnew/QS-2021-05-11_13-02-40.381095.txt https://finance.yahoo.com/news/quantumscape-announces-first-quarter-2021-201500516.html
# RGEN ./unsupnew/RGEN-2021-05-04_07-15-15.688215.txt https://finance.yahoo.com/news/repligen-reports-first-quarter-2021-113000798.html
# RNG ./unsupnew/RNG-2021-05-04_16-25-49.007922.txt https://finance.yahoo.com/news/ringcentral-announces-first-quarter-2021-200600324.html
# ROKU ./unsupnew/ROKU-2021-05-06_13-12-13.207778.txt https://finance.yahoo.com/news/roku-releases-first-quarter-2021-200300047.html
# RVLV ./unsupnew/RVLV-2021-05-06_13-05-16.184803.txt https://finance.yahoo.com/news/revolve-group-announces-first-quarter-200500204.html
# SQ ./unsupnew/SQ-2021-05-06_13-04-07.334717.txt https://finance.yahoo.com/news/square-inc-announces-first-quarter-200600101.html
# TTD ./unsupnew/TTD-2021-05-10_09-00-53.373685.txt https://finance.yahoo.com/news/trade-desk-reports-first-quarter-123000864.html
# TWLO ./unsupnew/TWLO-2021-05-05_16-25-11.208843.txt https://finance.yahoo.com/news/twilio-announces-first-quarter-2021-201000982.html
# UBER ./unsupnew/UBER-2021-05-05_16-56-26.864450.txt https://finance.yahoo.com/news/uber-announces-results-first-quarter-200500302.html
# VIR ./unsupnew/VIR-2021-05-06_13-05-40.023750.txt https://finance.yahoo.com/news/vir-biotechnology-provides-corporate-reports-200500093.html
# WD ./unsupnew/WD-2021-05-06_06-41-02.351639.txt https://finance.yahoo.com/news/walker-dunlop-reports-20-growth-100000820.html
# WIX ./unsupnew/WIX-2021-05-12_01-33-18.879147.txt https://finance.yahoo.com/news/wix-reports-first-quarter-2021-050000836.html
# WW ./unsupnew/WW-2021-05-05_16-28-00.873655.txt https://finance.yahoo.com/news/ww-announces-first-quarter-2021-200100511.html
# ZNGA ./unsupnew/ZNGA-2021-05-05_16-31-17.483618.txt https://finance.yahoo.com/news/zynga-announces-first-quarter-2021-200500864.html
# 50

# %%
import pandas as pd
import os
import re
import time
from selenium import webdriver

#url = (
#    "https://raw.githubusercontent.com/pandas-dev/pandas/master/"
#    "pandas/tests/io/data/html/spam.html"
#)

#url = "https://finance.yahoo.com/quote/SFIX/analysis?p=SFIX"
#url = "https://finance.yahoo.com/quote/SFIX/profile?p=SFIX"
#url = "https://finance.yahoo.com/quote/PINS/holders?p=PINS"
url = "https://finance.yahoo.com/quote/PINS/insider-roster?p=PINS"
#url = "https://finance.yahoo.com/quote/SFIX/key-statistics?p=SFIX"

driver = webdriver.Chrome()

driver.get(url)
time.sleep(2)

source = driver.page_source
#print(driver.page_source)
driver.close()
#Executive_pay
#profile = pd.read_html(url)
#profile

# %%
def getPgSource(url):
    driver = webdriver.Chrome()

    driver.get(url)
    time.sleep(2)

    source = driver.page_source
    #print(driver.page_source)
    driver.close()
    return(source)

# %%
profile = pd.read_html(source)
#print(len(profile), profile)
print(profile[0], profile[0].columns[0], profile[0].iloc[0,0], profile[0].iloc[1,0])
#print(profile[0],"\n")
#print(profile[0].loc[1])
#df = profile[0].loc[1]
#print(df, type(df), type(profile))
#print(df.loc["Current Qtr. (Sep 2021)"])
#print(profile[1].iloc[1,0], profile[1].columns[1], profile[1].iloc[1,1], profile[1].iloc[1,2], profile[1].iloc[1,3])
#print(df.loc["Current Qtr. *"])
#print(df["Avg. Estimate"])
# Out:
#                                 Individual or Entity  \
# 0                    FLORES CHRISTINEGeneral Counsel
# 1                               GAVINI NAVEENOfficer
# 2                        KILGORE LESLIE JEANDirector
# 3           MORGENFELD TODD RChief Financial Officer
# 4                              RAJARAM GOKULDirector
# 5                         REYNOLDS FREDRIC GDirector
# 6                             YANG TSELI LILYOfficer
# 7  *Insider roster data is derived solely from th...
#
#                              Most Recent Transaction  \
# 0                                               Sale
# 1                                               Sale
# 2                                 Stock Award(Grant)
# 3                                               Sale
# 4                                 Stock Award(Grant)
# 5                                 Stock Award(Grant)
# 6                                               Sale
# 7  *Insider roster data is derived solely from th...
#
#                                                 Date  \
# 0                                       Jun 27, 2021
# 1                                       Sep 12, 2021
# 2                                       May 27, 2021
# 3                                       Jun 27, 2021
# 4                                       May 27, 2021
# 5                                       May 27, 2021
# 6                                       Aug 26, 2021
# 7  *Insider roster data is derived solely from th...
#
#                  Shares Owned as of Transaction Date
# 0                                             294872
# 1                                             586267
# 2                                              27092
# 3                                             653039
# 4                                              37213
# 5                                              67092
# 6                                              59258
# 7  *Insider roster data is derived solely from th...   Individual or Entity FLORES CHRISTINEGeneral Counsel GAVINI NAVEENOfficer

# %%
DataExtract = [
    {
        "SOURCE":
        {
            "URL":"https://finance.yahoo.com/quote/*ORG/profile?p=*ORG"
        },
        "TABLE":
        {
            "NAME":"PROFILE",
            "TYPE":"SERIES"
        },
        "TUPLES":[
            {
                "CONDITIONS":[
                    {
                        "TABLENUM":0
                    }
                ],
                "ACTIONS":[
                    {
                        "KEY":
                        {
                            "ROW":-1,
                            "COLUMN":-1,
                            "MATCH":None,
                            "ALIAS":"EXECS"
                        }
                    }
                ]
            }
        ]
    },
    {
        "SOURCE":
        {
            "URL":"https://finance.yahoo.com/quote/*ORG/insider-transactions?p=*ORG"
        },
        "TABLE":
        {
            "NAME":"INSIDERTRANS",
            "TYPE":"SERIES"
        },
        "TUPLES":[
            {
                "CONDITIONS":[
                    {
                        "TABLENUM":0
                    }
                ],
                "ACTIONS":[
                    {
                        "KEY":
                        {
                            "ROW":-1,
                            "COLUMN":-1,
                            "MATCH":None,
                            "ALIAS":"TRANSSTAT"
                        }
                    }
                ]
            }
        ]
    },
    {
        "SOURCE":
        {
            "URL":"https://finance.yahoo.com/quote/*ORG/insider-roster?p=*ORG"
        },
        "TABLE":
        {
            "NAME":"MAJORTRANS",
            "TYPE":"SERIES"
        },
        "TUPLES":[
            {
                "CONDITIONS":[
                    {
                        "TABLENUM":0
                    }
                ],
                "ACTIONS":[
                    {
                        "KEY":
                        {
                            "ROW":-1,
                            "COLUMN":-1,
                            "MATCH":None,
                            "ALIAS":"ROSTERS"
                        }
                    }
                ]
            }
        ]
    },
    {
        "SOURCE":
        {
            "URL":"https://finance.yahoo.com/quote/*ORG/holders?p=*ORG"
        },
        "TABLE":
        {
            "NAME":"HOLDERS",
            "TYPE":"SERIES"
        },
        "TUPLES":[
            {
                "CONDITIONS":[
                    {
                        "TABLENUM":1
                    }
                ],
                "ACTIONS":[
                    {
                        "KEY":
                        {
                            "ROW":-1,
                            "COLUMN":-1,
                            "MATCH":None,
                            "ALIAS":"INST"
                        }
                    }
                ]
            },
            {
                "CONDITIONS":[
                    {
                        "TABLENUM":0
                    }
                ],
                "ACTIONS":[
                    {
                        "KEY":
                        {
                            "ROW":0,
                            "COLUMN":1,
                            "MATCH":"SHARES HELD BY ALL INSIDER",
                            "ALIAS":"INSIDERHELDPCT",
                            "VALUE":
                            {
                                "ROW":0,
                                "COLUMN":0
                            }
                        }
                    }
                ]
            },
            {
                "CONDITIONS":[
                    {
                        "TABLENUM":0
                    }
                ],
                "ACTIONS":[
                    {
                        "KEY":
                        {
                            "ROW":1,
                            "COLUMN":1,
                            "MATCH":"SHARES HELD BY INSTITUTIONS",
                            "ALIAS":"INSTHELDPCT",
                            "VALUE":
                            {
                                "ROW":1,
                                "COLUMN":0
                            }
                        }
                    }
                ]
            },
            {
                "CONDITIONS":[
                    {
                        "TABLENUM":0
                    }
                ],
                "ACTIONS":[
                    {
                        "KEY":
                        {
                            "ROW":2,
                            "COLUMN":1,
                            "MATCH":"FLOAT HELD BY INSTITUTIONS",
                            "ALIAS":"INSTHELDFLTPCT",
                            "VALUE":
                            {
                                "ROW":2,
                                "COLUMN":0
                            }
                        }
                    }
                ]
            },
            {
                "CONDITIONS":[
                    {
                        "TABLENUM":0
                    }
                ],
                "ACTIONS":[
                    {
                        "KEY":
                        {
                            "ROW":3,
                            "COLUMN":1,
                            "MATCH":"NUMBER OF INSTITUTIONS",
                            "ALIAS":"INSTNUM",
                            "VALUE":
                            {
                                "ROW":3,
                                "COLUMN":0
                            }
                        }
                    }
                ]
            }
        ]
    },
    {
        "SOURCE":
        {
            "URL":"https://finance.yahoo.com/quote/*ORG/analysis?p=*ORG"
        },
        "TABLE":
        {
            "NAME":"ANALYSIS",
            "TYPE":"FRAME"
        },
        "TUPLES":[
            {
                "CONDITIONS":[
                    {
                        "TABLENUM":2
                    }
                ],
                "ACTIONS":[
                    {
                        "KEY":
                        {
                            "COLUMN":1,
                            "MATCH":None,
                            "ALIAS":None,
                            "NAME":"EPS-ACT-HIST",
                            "VALUE":
                            {
                                "ROW":1,
                                "COLUMN":1
                            }
                        }
                    }
                ]
            },
            {
                "CONDITIONS":[
                    {
                        "TABLENUM":2
                    }
                ],
                "ACTIONS":[
                    {
                        "KEY":
                        {
                            "COLUMN":2,
                            "MATCH":None,
                            "ALIAS":None,
                            "NAME":"EPS-ACT-HIST",
                            "VALUE":
                            {
                                "ROW":1,
                                "COLUMN":2
                            }
                        }
                    }
                ]
            },
            {
                "CONDITIONS":[
                    {
                        "TABLENUM":2
                    }
                ],
                "ACTIONS":[
                    {
                        "KEY":
                        {
                            "COLUMN":3,
                            "MATCH":None,
                            "ALIAS":None,
                            "NAME":"EPS-ACT-HIST",
                            "VALUE":
                            {
                                "ROW":1,
                                "COLUMN":3
                            }
                        }
                    }
                ]
            },
            {
                "CONDITIONS":[
                    {
                        "TABLENUM":2
                    }
                ],
                "ACTIONS":[
                    {
                        "KEY":
                        {
                            "COLUMN":4,
                            "MATCH":None,
                            "ALIAS":None,
                            "NAME":"EPS-ACT-HIST",
                            "VALUE":
                            {
                                "ROW":1,
                                "COLUMN":4
                            }
                        }
                    }
                ]
            },
            {
                "CONDITIONS":[
                    {
                        "TABLENUM":2
                    }
                ],
                "ACTIONS":[
                    {
                        "KEY":
                        {
                            "COLUMN":1,
                            "MATCH":None,
                            "ALIAS":None,
                            "NAME":"EPS-EST-HIST",
                            "VALUE":
                            {
                                "ROW":0,
                                "COLUMN":1
                            }
                        }
                    }
                ]
            },
            {
                "CONDITIONS":[
                    {
                        "TABLENUM":2
                    }
                ],
                "ACTIONS":[
                    {
                        "KEY":
                        {
                            "COLUMN":2,
                            "MATCH":None,
                            "ALIAS":None,
                            "NAME":"EPS-EST-HIST",
                            "VALUE":
                            {
                                "ROW":0,
                                "COLUMN":2
                            }
                        }
                    }
                ]
            },
            {
                "CONDITIONS":[
                    {
                        "TABLENUM":2
                    }
                ],
                "ACTIONS":[
                    {
                        "KEY":
                        {
                            "COLUMN":3,
                            "MATCH":None,
                            "ALIAS":None,
                            "NAME":"EPS-EST-HIST",
                            "VALUE":
                            {
                                "ROW":0,
                                "COLUMN":3
                            }
                        }
                    }
                ]
            },
            {
                "CONDITIONS":[
                    {
                        "TABLENUM":2
                    }
                ],
                "ACTIONS":[
                    {
                        "KEY":
                        {
                            "COLUMN":4,
                            "MATCH":None,
                            "ALIAS":None,
                            "NAME":"EPS-EST-HIST",
                            "VALUE":
                            {
                                "ROW":0,
                                "COLUMN":4
                            }
                        }
                    }
                ]
            },
            {
                "CONDITIONS":[
                    {
                        "TABLENUM":1
                    }
                ],
                "ACTIONS":[
                    {
                        "KEY":
                        {
                            "COLUMN":1,
                            "MATCH":None,
                            "ALIAS":None,
                            "NAME":"REVENUE-EST",
                            "VALUE":
                            {
                                "ROW":1,
                                "COLUMN":1
                            }
                        }
                    }
                ]
            },
            {
                "CONDITIONS":[
                    {
                        "TABLENUM":1
                    }
                ],
                "ACTIONS":[
                    {
                        "KEY":
                        {
                            "COLUMN":2,
                            "MATCH":None,
                            "ALIAS":None,
                            "NAME":"REVENUE-EST",
                            "VALUE":
                            {
                                "ROW":1,
                                "COLUMN":2
                            }
                        }
                    }
                ]
            },
            {
                "CONDITIONS":[
                    {
                        "TABLENUM":1
                    }
                ],
                "ACTIONS":[
                    {
                        "KEY":
                        {
                            "COLUMN":3,
                            "MATCH":None,
                            "ALIAS":None,
                            "NAME":"REVENUE-EST",
                            "VALUE":
                            {
                                "ROW":1,
                                "COLUMN":3
                            }
                        }
                    }
                ]
            },
            {
                "CONDITIONS":[
                    {
                        "TABLENUM":1
                    }
                ],
                "ACTIONS":[
                    {
                        "KEY":
                        {
                            "COLUMN":4,
                            "MATCH":None,
                            "ALIAS":None,
                            "NAME":"REVENUE-EST",
                            "VALUE":
                            {
                                "ROW":1,
                                "COLUMN":4
                            }
                        }
                    }
                ]
            },
            {
                "CONDITIONS":[
                    {
                        "TABLENUM":0
                    }
                ],
                "ACTIONS":[
                    {
                        "KEY":
                        {
                            "COLUMN":1,
                            "MATCH":None,
                            "ALIAS":None,
                            "NAME":"EPS-EST",
                            "VALUE":
                            {
                                "ROW":1,
                                "COLUMN":1
                            }
                        }
                    }
                ]
            },
            {
                "CONDITIONS":[
                    {
                        "TABLENUM":0
                    }
                ],
                "ACTIONS":[
                    {
                        "KEY":
                        {
                            "COLUMN":2,
                            "MATCH":None,
                            "ALIAS":None,
                            "NAME":"EPS-EST",
                            "VALUE":
                            {
                                "ROW":1,
                                "COLUMN":2
                            }
                        }
                    }
                ]
            },
            {
                "CONDITIONS":[
                    {
                        "TABLENUM":0
                    }
                ],
                "ACTIONS":[
                    {
                        "KEY":
                        {
                            "COLUMN":3,
                            "MATCH":None,
                            "ALIAS":None,
                            "NAME":"EPS-EST",
                            "VALUE":
                            {
                                "ROW":1,
                                "COLUMN":3
                            }
                        }
                    }
                ]
            },
            {
                "CONDITIONS":[
                    {
                        "TABLENUM":0
                    }
                ],
                "ACTIONS":[
                    {
                        "KEY":
                        {
                            "COLUMN":4,
                            "MATCH":None,
                            "ALIAS":None,
                            "NAME":"EPS-EST",
                            "VALUE":
                            {
                                "ROW":1,
                                "COLUMN":4
                            }
                        }
                    }
                ]
            }
        ]
    },
    {      
        "SOURCE":
        {
            "URL":"https://finance.yahoo.com/quote/*ORG/key-statistics?p=*ORG"
        },
        "TABLE":
        {
            "NAME":"STATS",
            "TYPE":"SERIES"
        },
        "TUPLES":[
            {
                "CONDITIONS":[
                    {
                        "TABLENUM":9
                    }
                ],
                "ACTIONS":[
                    {
                        "KEY":
                        {
                            "ROW":1,
                            "COLUMN":0,
                            "MATCH":"LEVERED FREE CASH FLOW",
                            "ALIAS":"FCF",
                            "VALUE":
                            {
                                "ROW":1,
                                "COLUMN":1
                            }
                        }
                    }
                ]
            },
            {
                "CONDITIONS":[
                    {
                        "TABLENUM":8
                    }
                ],
                "ACTIONS":[
                    {
                        "KEY":
                        {
                            "ROW":0,
                            "COLUMN":0,
                            "MATCH":"TOTAL CASH",
                            "ALIAS":"CASH",
                            "VALUE":
                            {
                                "ROW":0,
                                "COLUMN":1
                            }
                        }
                    }
                ]
            },
            {
                "CONDITIONS":[
                    {
                        "TABLENUM":8
                    }
                ],
                "ACTIONS":[
                    {
                        "KEY":
                        {
                            "ROW":1,
                            "COLUMN":0,
                            "MATCH":"TOTAL CASH PER SHARE",
                            "ALIAS":"CASHPERSHARE",
                            "VALUE":
                            {
                                "ROW":1,
                                "COLUMN":1
                            }
                        }
                    }
                ]
            },
            {
                "CONDITIONS":[
                    {
                        "TABLENUM":8
                    }
                ],
                "ACTIONS":[
                    {
                        "KEY":
                        {
                            "ROW":2,
                            "COLUMN":0,
                            "MATCH":"TOTAL DEBT",
                            "ALIAS":"DEBT",
                            "VALUE":
                            {
                                "ROW":2,
                                "COLUMN":1
                            }
                        }
                    }
                ]
            },
            {
                "CONDITIONS":[
                    {
                        "TABLENUM":8
                    }
                ],
                "ACTIONS":[
                    {
                        "KEY":
                        {
                            "ROW":4,
                            "COLUMN":0,
                            "MATCH":"CURRENT RATIO",
                            "ALIAS":"CURRATIO",
                            "VALUE":
                            {
                                "ROW":4,
                                "COLUMN":1
                            }
                        }
                    }
                ]
            },
            {
                "CONDITIONS":[
                    {
                        "TABLENUM":6
                    }
                ],
                "ACTIONS":[
                    {
                        "KEY":
                        {
                            "ROW":0,
                            "COLUMN":0,
                            "MATCH":"RETURN ON ASSETS",
                            "ALIAS":"ROA",
                            "VALUE":
                            {
                                "ROW":0,
                                "COLUMN":1
                            }
                        }
                    }
                ]
            },
            {
                "CONDITIONS":[
                    {
                        "TABLENUM":6
                    }
                ],
                "ACTIONS":[
                    {
                        "KEY":
                        {
                            "ROW":1,
                            "COLUMN":0,
                            "MATCH":"RETURN ON EQUITY",
                            "ALIAS":"ROE",
                            "VALUE":
                            {
                                "ROW":1,
                                "COLUMN":1
                            }
                        }
                    }
                ]
            },
            {
                "CONDITIONS":[
                    {
                        "TABLENUM":4
                    }
                ],
                "ACTIONS":[
                    {
                        "KEY":
                        {
                            "ROW":0,
                            "COLUMN":0,
                            "MATCH":"FISCAL YEAR ENDS",
                            "ALIAS":"FISCALYEND",
                            "VALUE":
                            {
                                "ROW":0,
                                "COLUMN":1
                            }
                        }
                    }
                ]
            },
            {
                "CONDITIONS":[
                    {
                        "TABLENUM":4
                    }
                ],
                "ACTIONS":[
                    {
                        "KEY":
                        {
                            "ROW":1,
                            "COLUMN":0,
                            "MATCH":"MOST RECENT QUARTER",
                            "ALIAS":"MRQ",
                            "VALUE":
                            {
                                "ROW":1,
                                "COLUMN":1
                            }
                        }
                    }
                ]
            },
            {
                "CONDITIONS":[
                    {
                        "TABLENUM":3
                    }
                ],
                "ACTIONS":[
                    {
                        "KEY":
                        {
                            "ROW":1,
                            "COLUMN":0,
                            "MATCH":"FORWARD ANNUAL DIVIDEND YIELD",
                            "ALIAS":"FDIVYLD",
                            "VALUE":
                            {
                                "ROW":1,
                                "COLUMN":1
                            }
                        }
                    }
                ]
            },
            {
                "CONDITIONS":[
                    {
                        "TABLENUM":3
                    }
                ],
                "ACTIONS":[
                    {
                        "KEY":
                        {
                            "ROW":3,
                            "COLUMN":0,
                            "MATCH":"TRAILING ANNUAL DIVIDEND YIELD",
                            "ALIAS":"TDIVYLD",
                            "VALUE":
                            {
                                "ROW":3,
                                "COLUMN":1
                            }
                        }
                    }
                ]
            },
            {
                "CONDITIONS":[
                    {
                        "TABLENUM":3
                    }
                ],
                "ACTIONS":[
                    {
                        "KEY":
                        {
                            "ROW":5,
                            "COLUMN":0,
                            "MATCH":"PAYOUT RATIO",
                            "ALIAS":"PAYOUTRATIO",
                            "VALUE":
                            {
                                "ROW":5,
                                "COLUMN":1
                            }
                        }
                    }
                ]
            },
            {
                "CONDITIONS":[
                    {
                        "TABLENUM":3
                    }
                ],
                "ACTIONS":[
                    {
                        "KEY":
                        {
                            "ROW":6,
                            "COLUMN":0,
                            "MATCH":"DIVIDEND DATE",
                            "ALIAS":"DIVDATE",
                            "VALUE":
                            {
                                "ROW":6,
                                "COLUMN":1
                            }
                        }
                    }
                ]
            },
            {
                "CONDITIONS":[
                    {
                        "TABLENUM":3
                    }
                ],
                "ACTIONS":[
                    {
                        "KEY":
                        {
                            "ROW":7,
                            "COLUMN":0,
                            "MATCH":"EX-DIVIDEND DATE",
                            "ALIAS":"EXDIVDATE",
                            "VALUE":
                            {
                                "ROW":7,
                                "COLUMN":1
                            }
                        }
                    }
                ]
            },
            {
                "CONDITIONS":[
                    {
                        "TABLENUM":0
                    }
                ],
                "ACTIONS":[
                    {
                        "KEY":
                        {
                            "ROW":0,
                            "COLUMN":0,
                            "MATCH":"MARKET CAP",
                            "ALIAS":"MCAP",
                            "VALUE":
                            {
                                "ROW":0,
                                "COLUMN":1
                            }
                        }
                    }
                ]
            },
            {
                "CONDITIONS":[
                    {
                        "TABLENUM":0
                    }
                ],
                "ACTIONS":[
                    {
                        "KEY":
                        {
                            "ROW":5,
                            "COLUMN":0,
                            "MATCH":"PRICE/SALES",
                            "ALIAS":"PS",
                            "VALUE":
                            {
                                "ROW":5,
                                "COLUMN":1
                            }
                        }
                    }
                ]
            },
            {
                "CONDITIONS":[
                    {
                        "TABLENUM":1
                    }
                ],
                "ACTIONS":[
                    {
                        "KEY":
                        {
                            "ROW":5,
                            "COLUMN":0,
                            "MATCH":"50-DAY MOVING AVERAGE",
                            "ALIAS":"50DMA",
                            "VALUE":
                            {
                                "ROW":5,
                                "COLUMN":1
                            }
                        }
                    }
                ]
            },
            {
                "CONDITIONS":[
                    {
                        "TABLENUM":1
                    }
                ],
                "ACTIONS":[
                    {
                        "KEY":
                        {
                            "ROW":6,
                            "COLUMN":0,
                            "MATCH":"200-DAY MOVING AVERAGE",
                            "ALIAS":"200DMA",
                            "VALUE":
                            {
                                "ROW":6,
                                "COLUMN":1
                            }
                        }
                    }
                ]
            },
            {
                "CONDITIONS":[
                    {
                        "TABLENUM":2
                    }
                ],
                "ACTIONS":[
                    {
                        "KEY":
                        {
                            "ROW":0,
                            "COLUMN":0,
                            "MATCH":"AVG VOL (3 MONTH)",
                            "ALIAS":"AVGVOL3MONTH",
                            "VALUE":
                            {
                                "ROW":0,
                                "COLUMN":1
                            }
                        }
                    }
                ]
            },
            {
                "CONDITIONS":[
                    {
                        "TABLENUM":2
                    }
                ],
                "ACTIONS":[
                    {
                        "KEY":
                        {
                            "ROW":1,
                            "COLUMN":0,
                            "MATCH":"AVG VOL (10 DAY)",
                            "ALIAS":"AVGVOL10DAY",
                            "VALUE":
                            {
                                "ROW":1,
                                "COLUMN":1
                            }
                        }
                    }
                ]
            },
            {
                "CONDITIONS":[
                    {
                        "TABLENUM":2
                    }
                ],
                "ACTIONS":[
                    {
                        "KEY":
                        {
                            "ROW":9,
                            "COLUMN":0,
                            "MATCH":"SHORT % OF FLOAT",
                            "ALIAS":"SHORTPCTFLOAT",
                            "VALUE":
                            {
                                "ROW":9,
                                "COLUMN":1
                            }
                        }
                    }
                ]
            },
            {
                "CONDITIONS":[
                    {
                        "TABLENUM":2
                    }
                ],
                "ACTIONS":[
                    {
                        "KEY":
                        {
                            "ROW":10,
                            "COLUMN":0,
                            "MATCH":"SHORT % OF SHARES OUTSTANDING",
                            "ALIAS":"SHORTPCTOUST",
                            "VALUE":
                            {
                                "ROW":10,
                                "COLUMN":1
                            }
                        }
                    }
                ]
            }
        ]
    }
]
print(DataExtract)
# Out:
# [{'SOURCE': {'URL': 'https://finance.yahoo.com/quote/*ORG/profile?p=*ORG'}, 'TABLE': {'NAME': 'PROFILE', 'TYPE': 'SERIES'}, 'TUPLES': [{'CONDITIONS': [{'TABLENUM': 0}], 'ACTIONS': [{'KEY': {'ROW': -1, 'COLUMN': -1, 'MATCH': None, 'ALIAS': 'EXECS'}}]}]}, {'SOURCE': {'URL': 'https://finance.yahoo.com/quote/*ORG/insider-transactions?p=*ORG'}, 'TABLE': {'NAME': 'INSIDERTRANS', 'TYPE': 'SERIES'}, 'TUPLES': [{'CONDITIONS': [{'TABLENUM': 0}], 'ACTIONS': [{'KEY': {'ROW': -1, 'COLUMN': -1, 'MATCH': None, 'ALIAS': 'TRANSSTAT'}}]}]}, {'SOURCE': {'URL': 'https://finance.yahoo.com/quote/*ORG/insider-roster?p=*ORG'}, 'TABLE': {'NAME': 'MAJORTRANS', 'TYPE': 'SERIES'}, 'TUPLES': [{'CONDITIONS': [{'TABLENUM': 0}], 'ACTIONS': [{'KEY': {'ROW': -1, 'COLUMN': -1, 'MATCH': None, 'ALIAS': 'ROSTERS'}}]}]}, {'SOURCE': {'URL': 'https://finance.yahoo.com/quote/*ORG/holders?p=*ORG'}, 'TABLE': {'NAME': 'HOLDERS', 'TYPE': 'SERIES'}, 'TUPLES': [{'CONDITIONS': [{'TABLENUM': 1}], 'ACTIONS': [{'KEY': {'ROW': -1, 'COLUMN': -1, 'MATCH': None, 'ALIAS': 'INST'}}]}, {'CONDITIONS': [{'TABLENUM': 0}], 'ACTIONS': [{'KEY': {'ROW': 0, 'COLUMN': 1, 'MATCH': 'SHARES HELD BY ALL INSIDER', 'ALIAS': 'INSIDERHELDPCT', 'VALUE': {'ROW': 0, 'COLUMN': 0}}}]}, {'CONDITIONS': [{'TABLENUM': 0}], 'ACTIONS': [{'KEY': {'ROW': 1, 'COLUMN': 1, 'MATCH': 'SHARES HELD BY INSTITUTIONS', 'ALIAS': 'INSTHELDPCT', 'VALUE': {'ROW': 1, 'COLUMN': 0}}}]}, {'CONDITIONS': [{'TABLENUM': 0}], 'ACTIONS': [{'KEY': {'ROW': 2, 'COLUMN': 1, 'MATCH': 'FLOAT HELD BY INSTITUTIONS', 'ALIAS': 'INSTHELDFLTPCT', 'VALUE': {'ROW': 2, 'COLUMN': 0}}}]}, {'CONDITIONS': [{'TABLENUM': 0}], 'ACTIONS': [{'KEY': {'ROW': 3, 'COLUMN': 1, 'MATCH': 'NUMBER OF INSTITUTIONS', 'ALIAS': 'INSTNUM', 'VALUE': {'ROW': 3, 'COLUMN': 0}}}]}]}, {'SOURCE': {'URL': 'https://finance.yahoo.com/quote/*ORG/analysis?p=*ORG'}, 'TABLE': {'NAME': 'ANALYSIS', 'TYPE': 'FRAME'}, 'TUPLES': [{'CONDITIONS': [{'TABLENUM': 2}], 'ACTIONS': [{'KEY': {'COLUMN': 1, 'MATCH': None, 'ALIAS': None, 'NAME': 'EPS-ACT-HIST', 'VALUE': {'ROW': 1, 'COLUMN': 1}}}]}, {'CONDITIONS': [{'TABLENUM': 2}], 'ACTIONS': [{'KEY': {'COLUMN': 2, 'MATCH': None, 'ALIAS': None, 'NAME': 'EPS-ACT-HIST', 'VALUE': {'ROW': 1, 'COLUMN': 2}}}]}, {'CONDITIONS': [{'TABLENUM': 2}], 'ACTIONS': [{'KEY': {'COLUMN': 3, 'MATCH': None, 'ALIAS': None, 'NAME': 'EPS-ACT-HIST', 'VALUE': {'ROW': 1, 'COLUMN': 3}}}]}, {'CONDITIONS': [{'TABLENUM': 2}], 'ACTIONS': [{'KEY': {'COLUMN': 4, 'MATCH': None, 'ALIAS': None, 'NAME': 'EPS-ACT-HIST', 'VALUE': {'ROW': 1, 'COLUMN': 4}}}]}, {'CONDITIONS': [{'TABLENUM': 2}], 'ACTIONS': [{'KEY': {'COLUMN': 1, 'MATCH': None, 'ALIAS': None, 'NAME': 'EPS-EST-HIST', 'VALUE': {'ROW': 0, 'COLUMN': 1}}}]}, {'CONDITIONS': [{'TABLENUM': 2}], 'ACTIONS': [{'KEY': {'COLUMN': 2, 'MATCH': None, 'ALIAS': None, 'NAME': 'EPS-EST-HIST', 'VALUE': {'ROW': 0, 'COLUMN': 2}}}]}, {'CONDITIONS': [{'TABLENUM': 2}], 'ACTIONS': [{'KEY': {'COLUMN': 3, 'MATCH': None, 'ALIAS': None, 'NAME': 'EPS-EST-HIST', 'VALUE': {'ROW': 0, 'COLUMN': 3}}}]}, {'CONDITIONS': [{'TABLENUM': 2}], 'ACTIONS': [{'KEY': {'COLUMN': 4, 'MATCH': None, 'ALIAS': None, 'NAME': 'EPS-EST-HIST', 'VALUE': {'ROW': 0, 'COLUMN': 4}}}]}, {'CONDITIONS': [{'TABLENUM': 1}], 'ACTIONS': [{'KEY': {'COLUMN': 1, 'MATCH': None, 'ALIAS': None, 'NAME': 'REVENUE-EST', 'VALUE': {'ROW': 1, 'COLUMN': 1}}}]}, {'CONDITIONS': [{'TABLENUM': 1}], 'ACTIONS': [{'KEY': {'COLUMN': 2, 'MATCH': None, 'ALIAS': None, 'NAME': 'REVENUE-EST', 'VALUE': {'ROW': 1, 'COLUMN': 2}}}]}, {'CONDITIONS': [{'TABLENUM': 1}], 'ACTIONS': [{'KEY': {'COLUMN': 3, 'MATCH': None, 'ALIAS': None, 'NAME': 'REVENUE-EST', 'VALUE': {'ROW': 1, 'COLUMN': 3}}}]}, {'CONDITIONS': [{'TABLENUM': 1}], 'ACTIONS': [{'KEY': {'COLUMN': 4, 'MATCH': None, 'ALIAS': None, 'NAME': 'REVENUE-EST', 'VALUE': {'ROW': 1, 'COLUMN': 4}}}]}, {'CONDITIONS': [{'TABLENUM': 0}], 'ACTIONS': [{'KEY': {'COLUMN': 1, 'MATCH': None, 'ALIAS': None, 'NAME': 'EPS-EST', 'VALUE': {'ROW': 1, 'COLUMN': 1}}}]}, {'CONDITIONS': [{'TABLENUM': 0}], ...

# %%
import pandas as pd
import os
import re
import time
from selenium import webdriver

def GetTables(url):
    driver = webdriver.Chrome()

    driver.get(url)
    time.sleep(2)

    source = driver.page_source
    try:
        table = pd.read_html(source)
    except:
        return None
    #print(driver.page_source)
    driver.close()
    return table

# %%
def getOrgProfile(org):
    try:
        url = "https://www.alphavantage.co/query?function=OVERVIEW&symbol="+org+"&apikey=8NBLCOTKI465W93V"
        r = requests.get(url)
        data = r.json()
        return data
    except Exception as e:
        print(e)
        return None

# %%
def getOrgData(org):
    data = dict()
    orgProfile = getOrgProfile(org)
    if (not orgProfile):
        return None
    if("Symbol" not in orgProfile):
        print("INVALID PROFILE DATA, BAILING OUT")
        return None
    data["ORGPROFILE"] = orgProfile
    today = date.today()
    tstr = today.strftime("%B %d, %Y")
    data["LASTUPDATE"] = tstr
    for idx,rule in enumerate(DataExtract):
        #print(rule["SOURCE"]["URL"])
        url = rule["SOURCE"]["URL"]
        url = url.replace("*ORG", org)
        print(url)
        table = GetTables(url)
        #print(table)
        tableName = rule["TABLE"]["NAME"]
        tableType = rule["TABLE"]["TYPE"]
        print("TABLE NAME", tableName)
        data[tableName] = dict()
        if ("yahoo" in url):
            data[tableName]["SOURCE"] = "YH"
        #print(rule["TUPLES"])
        for tidx,tple in enumerate(rule["TUPLES"]):
            #print(tple)
            found = False
            for cidx,cnd in enumerate(tple["CONDITIONS"]):
                #print(cnd)
                if "TABLENUM" in cnd:
                    print("Table Number", cnd["TABLENUM"])
                    tableNum = cnd["TABLENUM"]
                    if len(table) >= tableNum:
                        found = True
                        print("FOUND")
                    break
            if(found):
                for aidx,act in enumerate(tple["ACTIONS"]):
                    #print(act)
                    if "KEY" in act:
                        if tableType == "SERIES":
                            rowKey = act["KEY"]["ROW"]
                            columnKey = act["KEY"]["COLUMN"]
                            matchRegex = act["KEY"]["MATCH"]
                            alias = act["KEY"]["ALIAS"]
                    
                            if(rowKey == -1 and columnKey == -1 and alias):
                                data[tableName][alias] = table[tableNum].to_json(orient="records")
                            else:
                                key = table[tableNum].iloc[rowKey,columnKey]
                                if(not matchRegex or (matchRegex and matchRegex in key.upper())):
                                    valueRow = act["KEY"]["VALUE"]["ROW"]
                                    valueColumn = act["KEY"]["VALUE"]["COLUMN"]
                                    value = table[tableNum].iloc[valueRow,valueColumn]
                                    print(rowKey, columnKey, key.upper(), valueRow, valueColumn, value)
                                    data[tableName][alias] = value
                        elif tableType == "FRAME":
                            columnNum = act["KEY"]["COLUMN"]
                            matchRegex = act["KEY"]["MATCH"]
                            alias = act["KEY"]["ALIAS"]
                            keyName = act["KEY"]["NAME"]
                            column = table[tableNum].columns[columnNum]
                        
                            if keyName not in data[tableName]:
                                data[tableName][keyName] = dict()
                        
                            if(not matchRegex or (matchRegex and matchRegex in column.upper())):
                                valueRow = act["KEY"]["VALUE"]["ROW"]
                                valueColumn = act["KEY"]["VALUE"]["COLUMN"]
                                value = table[tableNum].iloc[valueRow,valueColumn]
                                print(columnNum, column.upper(), valueRow, valueColumn, value)
                                if(alias):
                                    data[tableName][keyName][alias] = value
                                else:
                                    data[tableName][keyName][column] = value
    return data

# %%
import json
org = "PINS"
data = getOrgData(org)
dest = "../../Summary/orgData/"
if(data):
    print(data)
    json_object = json.dumps(data, indent = 4)
    file = dest+org+".txt"
  
    # Writing to sample.json
    with open(file, "w") as outfile:
        outfile.write(json_object)
# Out:
# https://finance.yahoo.com/quote/PINS/profile?p=PINS
# TABLE NAME PROFILE
# Table Number 0
# FOUND
# https://finance.yahoo.com/quote/PINS/insider-transactions?p=PINS
# TABLE NAME INSIDERTRANS
# Table Number 0
# FOUND
# https://finance.yahoo.com/quote/PINS/insider-roster?p=PINS
# TABLE NAME MAJORTRANS
# Table Number 0
# FOUND
# https://finance.yahoo.com/quote/PINS/holders?p=PINS
# TABLE NAME HOLDERS
# Table Number 1
# FOUND
# Table Number 0
# FOUND
# 0 1 % OF SHARES HELD BY ALL INSIDER 0 0 0.62%
# Table Number 0
# FOUND
# 1 1 % OF SHARES HELD BY INSTITUTIONS 1 0 79.17%
# Table Number 0
# FOUND
# 2 1 % OF FLOAT HELD BY INSTITUTIONS 2 0 79.67%
# Table Number 0
# FOUND
# 3 1 NUMBER OF INSTITUTIONS HOLDING SHARES 3 0 1093
# https://finance.yahoo.com/quote/PINS/analysis?p=PINS
# TABLE NAME ANALYSIS
# Table Number 2
# FOUND
# 1 9/29/2020 1 1 0.13
# Table Number 2
# FOUND
# 2 12/30/2020 1 2 0.43
# Table Number 2
# FOUND
# 3 3/30/2021 1 3 0.11
# Table Number 2
# FOUND
# 4 6/29/2021 1 4 0.25
# Table Number 2
# FOUND
# 1 9/29/2020 0 1 0.03
# Table Number 2
# FOUND
# 2 12/30/2020 0 2 0.32
# Table Number 2
# FOUND
# 3 3/30/2021 0 3 0.07
# Table Number 2
# FOUND
# 4 6/29/2021 0 4 0.13
# Table Number 1
# FOUND
# 1 CURRENT QTR. (SEP 2021) 1 1 631.08M
# Table Number 1
# FOUND
# 2 NEXT QTR. (DEC 2021) 1 2 876.87M
# Table Number 1
# FOUND
# 3 CURRENT YEAR (2021) 1 3 2.62B
# Table Number 1
# FOUND
# 4 NEXT YEAR (2022) 1 4 3.43B
# Table Number 0
# FOUND
# 1 CURRENT QTR. (SEP 2021) 1 1 0.23
# Table Number 0
# FOUND
# 2 NEXT QTR. (DEC 2021) 1 2 0.47
# Table Number 0
# FOUND
# 3 CURRENT YEAR (2021) 1 3 1.06
# Table Number 0
# FOUND
# 4 NEXT YEAR (2022) 1 4 1.39
# https://finance.yahoo.com/quote/PINS/key-statistics?p=PINS
# TABLE NAME STATS
# Table Number 9
# FOUND
# 1 0 LEVERED FREE CASH FLOW (TTM) 1 1 337.6M
# Table Number 8
# FOUND
# 0 0 TOTAL CASH (MRQ) 0 1 2.14B
# Table Number 8
# FOUND
# 1 0 TOTAL CASH PER SHARE (MRQ) 1 1 3.33
# Table Number 8
# FOUND
# 2 0 TOTAL DEBT (MRQ) 2 1 121.63M
# Table Number 8
# FOUND
# 4 0 CURRENT RATIO (MRQ) 4 1 11.22
# Table Number 6
# FOUND
# 0 0 RETURN ON ASSETS (TTM) 0 1 5.99%
# Table Number 6
# FOUND
# 1 0 RETURN ON EQUITY (TTM) 1 1 7.32%
# Table Number 4
# FOUND
# 0 0 FISCAL YEAR ENDS 0 1 Dec 30, 2020
# Table Number 4
# FOUND
# 1 0 MOST RECENT QUARTER (MRQ) 1 1 Jun 29, 2021
# Table Number 3
# FOUND
# 1 0 FORWARD ANNUAL DIVIDEND YIELD 4 1 1 nan
# Table Number 3
# FOUND
# 3 0 TRAILING ANNUAL DIVIDEND YIELD 3 3 1 nan
# Table Number 3
# FOUND
# 5 0 PAYOUT RATIO 4 5 1 0.00%
# Table Number 3
# FOUND
# 6 0 DIVIDEND DATE 3 6 1 nan
# Table Number 3
# FOUND
# 7 0 EX-DIVIDEND DATE 4 7 1 nan
# Table Number 0
# FOUND
# 0 0 MARKET CAP (INTRADAY) 5 0 1 33.92B
# Table Number 0
# FOUND
# 5 0 PRICE/SALES (TTM) 5 1 15.10
# Table Number 1
# FOUND
# 5 0 50-DAY MOVING AVERAGE 3 5 1 54.67
# Table Number 1
# FOUND
# 6 0 200-DAY MOVING AVERAGE 3 6 1 66.03
# Table Number 2
# FOUND
# 0 0 AVG VOL (3 MONTH) 3 0 1 10.13M
# Table Number 2
# FOUND
# 1 0 AVG VOL (10 DAY) 3 1 1 6.48M
# Table Number 2
# FOUND
# 9 0 SHORT % OF FLOAT (SEP 14, 2021) 4 9 1 3.07%
# Table Number 2
# FOUND
# 10 0 SHORT % OF SHARES OUTSTANDING (SEP 14, 2021) 4 10 1 2.63%
# {'ORGPROFILE': {'Symbol': 'PINS', 'AssetType': 'Common Stock', 'Name': 'Pinterest Inc', 'Description': 'Pinterest, Inc. provides a visual discovery engine in the United States and internationally. The company is headquartered in San Francisco, California.', 'CIK': '1506293', 'Exchange': 'NYSE', 'Currency': 'USD', 'Country': 'USA', 'Sector': 'TECHNOLOGY', 'Industry': 'SERVICES-COMPUTER PROGRAMMING, DATA PROCESSING, ETC.', 'Address': '808 BRANNAN STREET, SAN FRANCISCO, CA, US', 'FiscalYearEnd': 'December', 'LatestQuarter': '2021-06-30', 'MarketCapitalization': '33920377000', 'EBITDA': '276200000', 'PERatio': '208.81', 'PEGRatio': 'None', 'BookValue': '3.895', 'DividendPerShare': 'None', 'DividendYield': '0', 'EPS': '0.252', 'RevenuePerShareTTM': '3.614', 'ProfitMargin': '0.0718', 'OperatingMarginTTM': '0.11', 'ReturnOnAssetsTTM': '0.0599', 'ReturnOnEquityTTM': '0.0732', 'RevenueTTM': '2246673000', 'GrossProfitTTM': '1243300000', 'DilutedEPSTTM': '0.252', 'QuarterlyEarningsGrowthYOY': '0', 'QuarterlyRevenueGrowthYOY': '1.25', 'AnalystTargetPrice': '71.75', 'TrailingPE': '208.81', 'ForwardPE': '42.37', 'PriceToSalesRatioTTM': '15.1', 'PriceToBookRatio': '14.1', 'EVToRevenue': '14.82', 'EVToEBITDA': '171.51', 'Beta': '1.221', '52WeekHigh': '89.9', '52WeekLow': '42.32', '50DayMovingAverage': '54.73', '200DayMovingAverage': '66.08', 'SharesOutstanding': '555177000', 'SharesFloat': '552821000', 'SharesShort': '16979700', 'SharesShortPriorMonth': '17176800', 'ShortRatio': '2.21', 'ShortPercentOutstanding': '0.03', 'ShortPercentFloat': '0.0307', 'PercentInsiders': '0.619', 'PercentInstitutions': '79.17', 'ForwardAnnualDividendRate': '0', 'ForwardAnnualDividendYield': '0', 'PayoutRatio': '0', 'DividendDate': 'None', 'ExDividendDate': 'None', 'LastSplitFactor': 'None', 'LastSplitDate': 'None'}, 'LASTUPDATE': 'October 02, 2021', 'PROFILE': {'SOURCE': 'YH', 'EXECS': '[{"Name":"Mr. Benjamin Silbermann","Title":"Chairman, Co-Founder, Pres & CEO","Pay":"199.1k","Exercised":"229.48M","Year Born":1983.0},{"Name":"Mr. Evan Sharp","Title":"Co-Founder, Director and Chief Design & Creative Officer","Pay":"332k","Exercised":"76.44M","Year Born":1983.0},{"Name":"Mr. Todd R. Morgenfeld","Title":"CFO & Head of Bus. Operations","Pay":"362.5k","Exercised":null,"Year Born":1972.0},{"Name":"Ms. Christine Flores","Title":"Gen. Counsel & Sec.","Pay":"347k","Exercised":null,"Year Born":1975.0},{"Name":"Ms. Tse Li Yang","Title":"Chief Accounting Officer","Pay":null,"Exercised":null,"Year Born":1972.0},{"Name":"Ms. Jane Penner","Title":"Head of Investor Relations","Pay":null,"Exercised":null,"Year Born":null},{"Name":"Mr. John Kaplan","Title":"Head of Global Sales","Pay":null,"Exercised":null,"Year Born":null},{"Name":"Ms. Christine F. Deputy","Title":"Chief People Officer","Pay":null,"Exercised":null,"Year Born":1966.0},{"Name":"Mr. Randy Keller","Title":"Head of Search","Pay":null,"Exercised":null,"Year Born":null},{"Name":"Chuck Rosenberg","Title":"Head of Computer Vision Department","Pay":null,"Exercised":null,"Year Born":null}]'}, 'INSIDERTRANS': {'SOURCE': 'YH', 'TRANSSTAT': '[{"Insider Purchases Last 6 Months":"Purchases","Shares":"1923927","Trans":48.0},{"Insider Purchases Last 6 Months":"Sales","Shares":"2087276","Trans":52.0},{"Insider Purchases Last 6 Months":"Net Shares Purchased (Sold)","Shares":"-163349","Trans":100.0},{"Insider Purchases Last 6 Months":"Total Insider Shares Held","Shares":"3.99M","Trans":null},{"Insider Purchases Last 6 Months":"% Net Shares Purchased (Sold)","Shares":"-3.90%","Trans":null}]'}, 'MAJORTRANS': {'SOURCE': 'YH', 'ROSTERS': '[{"Individual or Entity":"FLORES CHRISTINEGeneral Counsel","Most Recent Transaction":"Sale","Date":"Jun 27, 2021","Shares Owned as of Transaction Date":"294872"},{"Individual or Entity":"GAVINI NAVEENOfficer","Most Recent Transaction":"Sale","Date":"Sep 12, 2021","Shares Owned as of Transaction Date":"586267"},{"Individual or Entity":"KILGORE LESLIE JEANDirector","Most Recent Transaction":"Stock Aw ...

# %%
import traceback
def getElement(element):
    try:
        elem = list()
        soup = BeautifulSoup(source, "html.parser")
        
        if(element == "PREVELEM"):
            cnt = -1
            for t in soup.find_all("div", class_="caas-table"):
                cnt = cnt + 1
                if t and t.previous_element:
                    #print("PREVIOUS ELEMENT "+str(cnt), t.previous_element)
                    #print("\n")
                    elem.append(str(t.previous_element).upper())
                else:
                    elem.append("NONE")
            return(elem)
    except Exception as e:
        print(e)
        print(traceback.format_exc())
        return None
    return None

# %%
import numpy as np
def findHeaders(table, match):
    hj = -1
    hstart = -1
    hend = -1
    #match = [str(cyr), str(pyr), str(nyr), nbr1, nbr2, nbr3]
    headers = list()
    
    for i in range(0,len(table)):
        for j in range(1,len(table.columns)):
            cell = table.iloc[i,j]
            if(table.iloc[i,0] == cell):
                #print(cell)
                table.iloc[i,j] = np.nan
    
    for i in range(0,len(table)):
        for j in range(1,len(table.columns)):
            cell = table.iloc[i,j]
            if(len(str(cell).split(" ")) < 10 and any(qtr in str(cell) for qtr in match)):
                print("HEADER CENTER", i, j)
                hj = i
                k = i
                hstart = -1
                hend = -1
                metric = table.iloc[k,0]
                # Multiple Headers may present inside single table
                if(len(headers) > 0):
                    #print(metric, k)
                    #hstart = i
                    while(str(metric) == "nan" and k>=0):
                        hstart = k 
                        k = k - 1
                        #print(metric, k)
                        if(k>=0):
                            metric = table.iloc[k,0]
                # Header always start from 0 index
                else:
                    hstart = 0
                if(i+1 < len(table)):
                    k = i+1
                    hend = i
                    metric = table.iloc[k,0]
                    while(str(metric) == "nan"):
                        hend = k 
                        #print("HEND", hend)
                        k = k + 1
                        metric = table.iloc[k,0]
                else:
                    hend = i
                print("HEADER BOUNDARY", hstart, hend)
                if(hstart > -1 and hend > -1):
                    hstr = str(hstart) + ":" + str(hend)
                    headers.append(hstr)
                    break
    
    return headers,table

# %%
def dedupHeaderColumns(header, report):
    mstr = None
    mindex = -1
    lvalidx = -1
    lvalsum = -1
    mdict = dict()
    
    # Check for columns where special character like $ present, need to preserve these columns in header
    rd = report.where(report=="$")
    rd = rd.dropna(axis=1, how="all")
    print("SPECIAL COLUMNS NEED TO BE PRESERVED")
    print(rd.columns)
    
    for i,v in enumerate(header.columns):
        #print(i,v)
        #print(header[v].astype(str).values)
        l = " ".join((header[v].astype(str).values))
        #print(l)
        # Find out which consecutive duplicate columns need to be removed
        if not mstr:
            mstr = l
            mindex = i
        else:
            if(l == mstr):
                if(lvalsum == -1):
                    lvalsum = report[v].isna().sum()
                    lvalidx = v
                if mindex not in mdict:
                    mdict[mindex] = list()
                    if(header.columns[i-1] not in rd.columns and v not in rd.columns):
                        if(report[header.columns[i-1]].isna().sum() > lvalsum):
                            mdict[mindex].append(header.columns[i-1])
                        else:
                            mdict[mindex].append(v)
                            lvalsum = report[v].isna().sum()
                            lvalidx = v
                    elif v in rd.columns and header.columns[i-1] in rd.columns:
                        mdict[mindex].append(v)
                        lvalsum = -2
                        lvalidx = header.columns[i-1]
                    elif v in rd.columns and header.columns[i-1] not in rd.columns:
                        mdict[mindex].append(header.columns[i-1])
                        lvalsum = -2
                        lvalidx = v
                    else:
                        mdict[mindex].append(v)
                        lvalsum = -2
                        lvalidx = header.columns[i-1]
                else:
                    if(report[v].isna().sum() >= lvalsum):
                        mdict[mindex].append(v)
                    else:
                        mdict[mindex].append(lvalidx)
                        lvalsum = report[v].isna().sum()
                        lvalidx = v
            else:
                mstr = l
                mindex = i
                lvalsum = -1
                lvalidx = -1
    print("DUPLICATE HEADER COLUMNS TO BE DELETED")
    print(mdict)
    for item in mdict:
        header = header.drop(mdict[item], axis=1)
    return header

# %%
tableRules = [
    {
        "SOURCE":["COLUMN:FIRST"], # Search within original first column name (renamed by "METRIC")
        "MATCH":"ANY",
        "CONDITIONS":["NON-GAAP FINANCIAL", "NON-GAAP OPERATING EXPENSES"],
        "ACTIONS":["ACCOUNTING"]
    },
    {
        "SOURCE":["COLUMN:FIRST"], # Search within original first column name (renamed by "METRIC")
        "MATCH":"ANY",
        "CONDITIONS":["NON-GAAP NET INCOME"],
        "ACTIONS":["ACCOUNTING"]
    },
    {
        "SOURCE":["COLUMN:FIRST"], # Search within original first column name (renamed by "METRIC")
        "MATCH":"ANY",
        "CONDITIONS":["NON-GAAP GROSS PROFIT"],
        "ACTIONS":["ACCOUNTING"]
    },
    {
        "SOURCE":["COLUMN:FIRST"], # Search within original first column name (renamed by "METRIC")
        "MATCH":"ANY",
        "CONDITIONS":["STATEMENTS OF INCOME"],
        "ACTIONS":["ACCOUNTING"]
    },
    {
        "SOURCE":["COLUMN:FIRST"], # Search within original first column name (renamed by "METRIC")
        "MATCH":"EXACT",
        "CONDITIONS":["ASSETS"],
        "ACTIONS":["BALANCESHEET"]
    },
    {
        "SOURCE":["COLUMN:FIRST"], # Search within original first column name (renamed by "METRIC")
        "MATCH":"ANY",
        "CONDITIONS":["SEGMENTED ADJUSTED GROSS MARGIN"],
        "ACTIONS":["SEGNGGM"]
    },
    {
        "SOURCE":["COLUMN:FIRST"], # Search within original first column name (renamed by "METRIC")
        "MATCH":"ANY",
        "CONDITIONS":["ADJUSTED GROSS MARGIN"],
        "ACTIONS":["NGGM"]
    },
    {
        "SOURCE":["COLUMN:FIRST"], # Search within original first column name (renamed by "METRIC")
        "MATCH":"ANY",
        "CONDITIONS":["SEGMENTED GROSS MARGIN"],
        "ACTIONS":["SEGGM"]
    },
    {
        "SOURCE":["COLUMN:FIRST"], # Search within original first column name (renamed by "METRIC")
        "MATCH":"ANY",
        "CONDITIONS":["ADJUSTED EBITDA"],
        "ACTIONS":["NGEBITDA"]
    },
    {
        "SOURCE":["COLUMN:FIRST"], # Search table description
        "MATCH":"ANY",
        "CONDITIONS":["EARNINGS BEFORE INTEREST AND TAXES"],
        "ACTIONS":["NGEBIT"]
    },
    {
        "SOURCE":["COLUMN:FIRST"], # Search within original first column name (renamed by "METRIC")
        "MATCH":"ANY",
        "CONDITIONS":["DIVISIONAL REVENUES"],
        "ACTIONS":["REVENUECHN"]
    },
    {
        "SOURCE":["COLUMN:METRIC"],
        "MATCH":"EXACT",
        "CONDITIONS":["ADJUSTED EBITDA MARGIN"],
        "ACTIONS":["HIGHLIGHT"]
    },
    {
        "SOURCE":["COLUMN:METRIC"],
        "MATCH":"EXACT",
        "CONDITIONS":["TOTAL CURRENT ASSETS"],
        "ACTIONS":["BALANCESHEET"]
    },
    {
        "SOURCE":["COLUMN:METRIC"],
        "MATCH":"EXACT",
        "CONDITIONS":["FREE CASH FLOW"],
        "ACTIONS":["FCF"]
    },
    {
        "SOURCE":["COLUMN:METRIC"],
        "MATCH":"EXACT",
        "CONDITIONS":["COST OF REVENUE"],
        "ACTIONS":["STMTOP"]
    },
    {
        "SOURCE":["COLUMN:METRIC"],
        "MATCH":"EXACT",
        "CONDITIONS":["COST OF SALES"],
        "ACTIONS":["STMTOP"]
    },
    {
        "SOURCE":["COLUMN:METRIC"],
        "MATCH":"ANY",
        "CONDITIONS":["PER SHARE DATA"],
        "ACTIONS":["PERSHARE"]
    },
    {
        "SOURCE":["COLUMN:METRIC"],
        "MATCH":"ANY",
        "CONDITIONS":["NET INVESTMENT INCOME"],
        "ACTIONS":["STMTOP"]
    },
    {
        "SOURCE":["COLUMN:METRIC"],
        "MATCH":"EXACT",
        "CONDITIONS":["COST OF GOODS SOLD"],
        "ACTIONS":["STMTOP"]
    },
    {
        "SOURCE":["COLUMN:METRIC"],
        "MATCH":"EXACT",
        "CONDITIONS":["OPERATING ACTIVITIES"],
        "ACTIONS":["STMTCASHFLOW"]
    },
    {
        "SOURCE":["COLUMN:METRIC"],
        "MATCH":"EXACT",
        "CONDITIONS":["CASH, ENDING"],
        "ACTIONS":["STMTCASHFLOW"]
    },
    {
        "SOURCE":["COLUMN:METRIC"],
        "MATCH":"EXACT",
        "CONDITIONS":["CASH FLOWS FROM OPERATING ACTIVITIES"],
        "ACTIONS":["STMTCASHFLOW"]
    },
    {
        "SOURCE":["COLUMN:METRIC"],
        "MATCH":"EXACT",
        "CONDITIONS":["CASH FLOWS FROM OPERATING ACTIVITIES:"],
        "ACTIONS":["STMTCASHFLOW"]
    },
    {
        "SOURCE":["COLUMN:METRIC"], # Search data only from "METRIC" column
        "MATCH":"ANY",
        "CONDITIONS":["ARPU", "MAUS", "LOSS RATIO", "GROSS WRITTEN PREMIUMS", "ACTIVE BUYERS", "ACTIVE CLIENTS", "ASSETS AT FLOATING RATES", "NUMBER OF PORTFOLIO COMPANIES", "TOTAL ORIGINATIONS", "# OF INVESTMENTS"],
        "ACTIONS":["OPMETRIC"]
    },
    {
        "SOURCE":["COLUMN:METRIC"],
        "MATCH":"EXACT",
        "CONDITIONS":["GAAP INCOME FROM OPERATIONS"],
        "ACTIONS":["ACCOUNTING"]
    },
    {
        "SOURCE":["COLUMN:ANY"], # No specific column name, search any column name
        "MATCH":"ANY", # Match any condition
        "CONDITIONS":["GUIDANCE"],
        "ACTIONS":["GUIDANCE"]
    },
    {
        "SOURCE":["DESCRIPTION:ANY"], # Search table description
        "MATCH":"ANY",
        "CONDITIONS":["GUIDANCE", "OUTLOOK"],
        "ACTIONS":["GUIDANCE"]
    },
    {
        "SOURCE":["DESCRIPTION:ANY"], # Search table description
        "MATCH":"ANY",
        "CONDITIONS":["ADJUSTED EBITDA"],
        "ACTIONS":["NGEBITDA"]
    },
    {
        "SOURCE":["DESCRIPTION:ANY"], # Search table description
        "MATCH":"ANY",
        "CONDITIONS":["GAAP FINANCIAL METRICS"],
        "ACTIONS":["ACCOUNTING"]
    },
    {
        "SOURCE":["DESCRIPTION:ANY"], # Search table description
        "MATCH":"EXACT",
        "CONDITIONS":["NET REVENUE"],
        "ACTIONS":["REVENUE"]
    },
    {
        "SOURCE":["DESCRIPTION:ANY"], # Search table description
        "MATCH":"EXACT",
        "CONDITIONS":["REVENUE BY CHANNEL"],
        "ACTIONS":["REVENUECHN"]
    },
    {
        "SOURCE":["DESCRIPTION:ANY"], # Search table description
        "MATCH":"EXACT",
        "CONDITIONS":["REVENUE BY FORM"],
        "ACTIONS":["REVENUEFORM"]
    },
    {
        "SOURCE":["DESCRIPTION:ANY"],
        "MATCH":"EXACT",
        "CONDITIONS":["FINANCIAL RESULTS"],
        "ACTIONS":["STMTOP"]
    },
    {
        "SOURCE":["DESCRIPTION:ANY"], # Search table description
        "MATCH":"EXACT",
        "CONDITIONS":["ADJUSTED GROSS MARGIN"],
        "ACTIONS":["NGGM"] # Non-GAAP Gross Margin
    },
    {
        "SOURCE":["DESCRIPTION:ANY"], # Search table description
        "MATCH":"ANY",
        "CONDITIONS":["OPERATING METRIC"],
        "ACTIONS":["OPMETRIC"]
    }
]
print(tableRules)
# Out:
# [{'SOURCE': ['COLUMN:FIRST'], 'MATCH': 'ANY', 'CONDITIONS': ['NON-GAAP FINANCIAL', 'NON-GAAP OPERATING EXPENSES'], 'ACTIONS': ['ACCOUNTING']}, {'SOURCE': ['COLUMN:FIRST'], 'MATCH': 'ANY', 'CONDITIONS': ['NON-GAAP NET INCOME'], 'ACTIONS': ['ACCOUNTING']}, {'SOURCE': ['COLUMN:FIRST'], 'MATCH': 'ANY', 'CONDITIONS': ['NON-GAAP GROSS PROFIT'], 'ACTIONS': ['ACCOUNTING']}, {'SOURCE': ['COLUMN:FIRST'], 'MATCH': 'ANY', 'CONDITIONS': ['STATEMENTS OF INCOME'], 'ACTIONS': ['ACCOUNTING']}, {'SOURCE': ['COLUMN:FIRST'], 'MATCH': 'EXACT', 'CONDITIONS': ['ASSETS'], 'ACTIONS': ['BALANCESHEET']}, {'SOURCE': ['COLUMN:FIRST'], 'MATCH': 'ANY', 'CONDITIONS': ['SEGMENTED ADJUSTED GROSS MARGIN'], 'ACTIONS': ['SEGNGGM']}, {'SOURCE': ['COLUMN:FIRST'], 'MATCH': 'ANY', 'CONDITIONS': ['ADJUSTED GROSS MARGIN'], 'ACTIONS': ['NGGM']}, {'SOURCE': ['COLUMN:FIRST'], 'MATCH': 'ANY', 'CONDITIONS': ['SEGMENTED GROSS MARGIN'], 'ACTIONS': ['SEGGM']}, {'SOURCE': ['COLUMN:FIRST'], 'MATCH': 'ANY', 'CONDITIONS': ['ADJUSTED EBITDA'], 'ACTIONS': ['NGEBITDA']}, {'SOURCE': ['COLUMN:FIRST'], 'MATCH': 'ANY', 'CONDITIONS': ['EARNINGS BEFORE INTEREST AND TAXES'], 'ACTIONS': ['NGEBIT']}, {'SOURCE': ['COLUMN:FIRST'], 'MATCH': 'ANY', 'CONDITIONS': ['DIVISIONAL REVENUES'], 'ACTIONS': ['REVENUECHN']}, {'SOURCE': ['COLUMN:METRIC'], 'MATCH': 'EXACT', 'CONDITIONS': ['ADJUSTED EBITDA MARGIN'], 'ACTIONS': ['HIGHLIGHT']}, {'SOURCE': ['COLUMN:METRIC'], 'MATCH': 'EXACT', 'CONDITIONS': ['TOTAL CURRENT ASSETS'], 'ACTIONS': ['BALANCESHEET']}, {'SOURCE': ['COLUMN:METRIC'], 'MATCH': 'EXACT', 'CONDITIONS': ['FREE CASH FLOW'], 'ACTIONS': ['FCF']}, {'SOURCE': ['COLUMN:METRIC'], 'MATCH': 'EXACT', 'CONDITIONS': ['COST OF REVENUE'], 'ACTIONS': ['STMTOP']}, {'SOURCE': ['COLUMN:METRIC'], 'MATCH': 'EXACT', 'CONDITIONS': ['COST OF SALES'], 'ACTIONS': ['STMTOP']}, {'SOURCE': ['COLUMN:METRIC'], 'MATCH': 'ANY', 'CONDITIONS': ['PER SHARE DATA'], 'ACTIONS': ['PERSHARE']}, {'SOURCE': ['COLUMN:METRIC'], 'MATCH': 'ANY', 'CONDITIONS': ['NET INVESTMENT INCOME'], 'ACTIONS': ['STMTOP']}, {'SOURCE': ['COLUMN:METRIC'], 'MATCH': 'EXACT', 'CONDITIONS': ['COST OF GOODS SOLD'], 'ACTIONS': ['STMTOP']}, {'SOURCE': ['COLUMN:METRIC'], 'MATCH': 'EXACT', 'CONDITIONS': ['OPERATING ACTIVITIES'], 'ACTIONS': ['STMTCASHFLOW']}, {'SOURCE': ['COLUMN:METRIC'], 'MATCH': 'EXACT', 'CONDITIONS': ['CASH, ENDING'], 'ACTIONS': ['STMTCASHFLOW']}, {'SOURCE': ['COLUMN:METRIC'], 'MATCH': 'EXACT', 'CONDITIONS': ['CASH FLOWS FROM OPERATING ACTIVITIES'], 'ACTIONS': ['STMTCASHFLOW']}, {'SOURCE': ['COLUMN:METRIC'], 'MATCH': 'EXACT', 'CONDITIONS': ['CASH FLOWS FROM OPERATING ACTIVITIES:'], 'ACTIONS': ['STMTCASHFLOW']}, {'SOURCE': ['COLUMN:METRIC'], 'MATCH': 'ANY', 'CONDITIONS': ['ARPU', 'MAUS', 'LOSS RATIO', 'GROSS WRITTEN PREMIUMS', 'ACTIVE BUYERS', 'ACTIVE CLIENTS', 'ASSETS AT FLOATING RATES', 'NUMBER OF PORTFOLIO COMPANIES', 'TOTAL ORIGINATIONS', '# OF INVESTMENTS'], 'ACTIONS': ['OPMETRIC']}, {'SOURCE': ['COLUMN:METRIC'], 'MATCH': 'EXACT', 'CONDITIONS': ['GAAP INCOME FROM OPERATIONS'], 'ACTIONS': ['ACCOUNTING']}, {'SOURCE': ['COLUMN:ANY'], 'MATCH': 'ANY', 'CONDITIONS': ['GUIDANCE'], 'ACTIONS': ['GUIDANCE']}, {'SOURCE': ['DESCRIPTION:ANY'], 'MATCH': 'ANY', 'CONDITIONS': ['GUIDANCE', 'OUTLOOK'], 'ACTIONS': ['GUIDANCE']}, {'SOURCE': ['DESCRIPTION:ANY'], 'MATCH': 'ANY', 'CONDITIONS': ['ADJUSTED EBITDA'], 'ACTIONS': ['NGEBITDA']}, {'SOURCE': ['DESCRIPTION:ANY'], 'MATCH': 'ANY', 'CONDITIONS': ['GAAP FINANCIAL METRICS'], 'ACTIONS': ['ACCOUNTING']}, {'SOURCE': ['DESCRIPTION:ANY'], 'MATCH': 'EXACT', 'CONDITIONS': ['NET REVENUE'], 'ACTIONS': ['REVENUE']}, {'SOURCE': ['DESCRIPTION:ANY'], 'MATCH': 'EXACT', 'CONDITIONS': ['REVENUE BY CHANNEL'], 'ACTIONS': ['REVENUECHN']}, {'SOURCE': ['DESCRIPTION:ANY'], 'MATCH': 'EXACT', 'CONDITIONS': ['REVENUE BY FORM'], 'ACTIONS': ['REVENUEFORM']}, {'SOURCE': ['DESCRIPTION:ANY'], 'MATCH': 'EXACT', 'CONDITIONS': ['FINANCIAL RESULTS'], 'ACTIONS': ['STMTOP']}, {'SOURCE': ['DESCRIPTION:ANY'], 'MATCH': 'EXACT', 'CONDITIONS': ['ADJUST ...

# %%
import traceback
def getOneTable(tables, tableNum, tblDesc):
    if not tables:
        print("TABLES CORRUPTED")
        return None
    if(tableNum >= len(tables)):
        print("INVALID TABLE INDEX")
        return None
    try:
        
        todays_date = date.today()
        cyr = todays_date.year
        pyr = cyr - 1
        nyr = cyr + 1
        nbr = str(nyr)[2:4]
        nbr1 = "FY’"+nbr
        nbr2 = "FY"+nbr
        nbr3 = "’"+nbr
        
        hdmatch = [str(cyr), str(pyr), str(nyr), nbr1, nbr2, nbr3]
        
        mn = ["MILLIONS", "MILLION", "millions", "million"]
        bn = ["BILLIONS", "BILLION", "billions", "billion"]
        t = ["THOUSANDS", "THOUSAND", "thousands", "thousand", "$000"]
        
        stmt = tables[tableNum]
        print("ORIGINAL TABLE")
        print(stmt)
    
        #stmt=stmt.T.drop_duplicates().T
        stmt = stmt.dropna(axis=1, how="all")
        stmt = stmt.dropna(axis=0, how="all")
        print("TABLE AFTER REMOVING DUPLICATE ROWS AND COLUMNS")
        print(stmt)
    
        headers,stmt = findHeaders(stmt, hdmatch)
        print(headers)
    
        if(len(headers) == 0):
            print("INVALID TABLE, HEADER NOT FOUND")
            return None
    
        print("TABLE AFTER REMOVING DUPLICATES")
        print(stmt)
    
        #Itereate through headers
        cnt = 0
        ft = dict()
        for i in list(headers):
            #print(i)
            tblName = None
            tblType = None
            cnt = cnt + 1
            hstart = int(i.split(":")[0])
            hend = int(i.split(":")[1])
            if(len(headers) > cnt):
                rend = int(headers[cnt].split(":")[0])
            else:
                rend = len(stmt)
            print("\nHEADER START", hstart, "HEADER END", hend, "REPORT END", rend)
            header = stmt.iloc[hstart:hend+1,0:]
            #header = header.dropna(axis=1, how="all")
            report = stmt.iloc[hend+1:rend,0:]
            #report = report.dropna(axis=1, how="all")
            print("\nHEADER "+str(cnt))
            print(header)
            print("\nREPORT "+str(cnt))
            print(report)
            
            header = dedupHeaderColumns(header, report)
            
            print("\nAFTER DELETING DUPLICATE COLUMN HEADER")
            print("\nHEADER "+str(cnt))
            print(header)
            
            if(len(header) == 0):
                print("NO HEADER FOUND")
                return None
            
            header1 = header[0]
            print("HEADER BATCH 1")
            print(header1)
            
            header2 = header[header.columns[1:]]
            header2 = header2.dropna(axis=1, how="all")
            
            hddrop = list()
            for hd in list(header2.columns):
                if(header2[hd].str.contains("|".join(hdmatch)).sum() == 0):
                    hddrop.append(hd)
            
            print("\nINVALID HEADER")
            print(hddrop)
            header2 = header2.drop(hddrop, axis=1)
            print("HEADER BATCH 2")
            print(header2)
            
            header = pd.concat([header1, header2], axis=1, join='inner')
            header[header.columns[0:]] = header[header.columns[0:]].astype(str)
            #print(header)
            header[header.columns[0:]] = header[header.columns[0:]].applymap(lambda x: re.sub(r'\(\d+\)|\(\d+[a-zA-Z]\)*|\*', r'', x))
            print("FINAL HEADER")
            print(header)
            
            #report = report.T.drop_duplicates().T
            report = report.dropna(axis=1, how="all")
            
            print("\nAFTER DELETING DUPLICATE ROWS")
            print("\nREPORT "+str(cnt))
            print(report)
            
            if(len(report) > 0):
            
                # Merge REPORT columns present with special characters - e.g. $/% etc...
                rd = report.where(report=="$")
                rd = rd.dropna(axis=1, how="all")
                print("\nSPECIAL COLUMNS")
                print(rd.columns)
                dropList = list()
                #print(rd.columns)
                for i in list(rd.columns):
                    #print(report[i])
                    report[i] = report[i].map(lambda x: "" if str(x) != "$" else x)
                    k = i + 1
                    while(k in list(rd.columns)):
                        dropList.append(k)
                        #rd.columns = list(rd.columns).remove(k)
                        k = k + 1
                    report[i] = report[i] + report[k]
                    dropList.append(k)
                report = report.drop(dropList, axis=1)
                report[report.columns[1:]] = report[report.columns[1:]].astype(str)
                report[report.columns[1:]] = report[report.columns[1:]].applymap(lambda x: x.replace('$(','-$'))
                report[report.columns[1:]] = report[report.columns[1:]].applymap(lambda x: x.replace('(','-'))
                report[report.columns[1:]] = report[report.columns[1:]].applymap(lambda x: x.replace(')',''))
                report[report.columns[1:]] = report[report.columns[1:]].applymap(lambda x: x.replace(',',''))
                report[0] = report[0].str.replace(":","")
                report[0] = report[0].str.replace(r'\d+|\(\d+\)|\(\d+[a-zA-Z]\)*|\*', r'')
                report[0] = report[0].str.upper()
                #report[report.columns[1:]] = report[report.columns[1:]].astype(float)
            
                rd = report.where(report=="%")
                rd = rd.dropna(axis=1, how="all")
                #print(rd)
                dropList = list()
                mgclmn = -1
                #print(rd.columns)
                for i in list(rd.columns):
                    #print(report[i])
                    report[i] = report[i].map(lambda x: "" if str(x) != "%" else x)
                    mgclmn = i - 1
                    while(mgclmn>=0):
                        if mgclmn not in header.columns:
                            mgclmn = mgclmn - 1
                        else:
                            #print(mgclmn,i)              
                            report[mgclmn] = report[mgclmn] + report[i]
                            dropList.append(i)
                            break
                report = report.drop(dropList, axis=1)
                print("\nREPORT AFTER MERGING SPECIAL COLUMNS")
                print(report)
            
                hdclmn = header.columns
                rclmn = report.columns
                print("\nHEADER COLUMNS", hdclmn)
                print("REPORT COLUMNS", rclmn)
            
                if(len(hdclmn) == 1 and len(header) == 1):
                    #print("SINGLE COLUMN")
                    if(str(header.iloc[0,0]) == "nan"):
                        print("INVALID HEADER CONTENT FOR SINGLE COLUMN, BAILING OUT")
                        return None
                    s = header.iloc[0,0]
                    #Remove special characters
                    s = re.sub('[^a-zA-Z0-9 \n\.]', '', s)
                    #print(s)
                    data = list()
                    data = [str(s)+"***"+str(item) for item in list(rclmn)]
                    header = pd.DataFrame(np.array([data]),columns=rclmn)
                    hdclmn = header.columns
                    print("NEW HEADER COLUMNS", hdclmn)
            
            
                finalClmns = hdclmn.intersection(rclmn)
                print("INTERSECTION COLUMNS",finalClmns)
                header = header[finalClmns]
                print("FINAL HEADER")
                print(header)
            
                hstr = list()
            
                count = -1
                for i in list(header.columns):
                    count = count + 1
                    l = header[i].astype(str).values
                    l = ' '.join(dict.fromkeys(l))
                    l = l.replace("-nan","-")
                    l = l.replace("nan-","")
                    l = l.replace("nan ","")
                    l = l.replace(" nan","")
                    l = l.replace(" nan ","")
                    l = l.strip()
                    #print(hstr)
                    if l.upper() in hstr:
                        l = l+"***"+str(count)
                    hstr.append(l.upper())
                    #print(l)
            
                tblType = hstr[0]
                print("\nORIGINAL FIRST COLUMN NAME")
                print(tblType)
            
                print("\nTABLE DESCRIPTION")
                print(tblDesc)
            
                hstr[0] = "METRIC"
                print("\nFINAL HEADER STRING")
                print(hstr)
            
                report = report[finalClmns]
                report.columns = hstr
                print("\nFINAL REPORT")
                print(report)
            
                #print("\nREPORT COLUMNS")
                #print(report.columns)
            else:
                print("EMPTY REPORT, ASSIGN HEADER TO REPORT")
                hclmn = list(header.columns)
                #print(hclmn)
                hclmn[0] = "METRIC"
                report = header
                hclmn = map(lambda x: str(x), hclmn)
                report.columns = (hclmn)
                print(report)
                #report.columns[0] = "METRIC"
            
            # Select unit of the table numbers
            unit = "T"
            for word in (mn+bn+t):
                if((tblType and word in tblType) or (tblDesc and word in tblDesc) or report["METRIC"].str.contains(word).sum() > 0):
                    if word in mn:
                        unit = "M"
                        break
                    elif word in bn:
                        unit = "B"
                        break
                    else:
                        unit = "T"
                        break
            
            # Select table type
            for item in list(tableRules):
                source = (item["SOURCE"][0])
                stype = item["SOURCE"][0].split(":")[0]
                sval = item["SOURCE"][0].split(":")[1]
                condition = item["CONDITIONS"][0]
                match = item["MATCH"]
                action = item["ACTIONS"][0]
                #print(match, condition, sval)
                #print(condition)
                
                if(stype == "COLUMN"):
                    if(sval == "FIRST"):
                        if match == "EXACT" and tblType and tblType == condition:
                            tblName = action
                            break
                        elif match == "ANY" and tblType and any(word in tblType for word in item["CONDITIONS"]):
                            tblName = action
                            break
                    elif(sval != "ANY"):
                        if match == "EXACT" and report[sval].eq(condition).sum()> 0:
                            #print("TABLE NAME BALANCESHEET")
                            tblName = action
                            break
                        elif match == "ANY" and report[sval].str.contains("|".join(item["CONDITIONS"])).sum()> 0:
                            tblName = action
                            break
                    else:
                        if(match == "ANY" and any(s in " ".join(report.columns) for s in item["CONDITIONS"])):
                            tblName = action
                            break
                        elif(match == "EXACT" and any(s in (report.columns) for s in item["CONDITIONS"])):
                            tblName = action
                            break
                elif(stype == "DESCRIPTION"):
                    if(sval == "ANY"):
                        #print(match)
                        #print("|".join(item["CONDITIONS"]))
                        if match == "EXACT" and tblDesc and tblDesc == condition:
                            tblName = action
                            break
                        elif match == "ANY" and tblDesc and any(word in tblDesc for word in item["CONDITIONS"]):
                            tblName = action
                            break
                
            if not tblName:
                ft[str(tableNum)+":"+unit+":"+"OTHER"+":"+str(cnt)] = report.to_json(orient="records")
            else:
                ft[str(tableNum)+":"+unit+":"+tblName+":"+str(cnt)] = report.to_json(orient="records")
            #print(ft)
        return(ft)
    except Exception as e:
        print("EXCEPTION:", e)
        print(traceback.format_exc())
        return None

# %%
#url = "https://finance.yahoo.com/news/pinterest-announces-second-quarter-2021-200500141.html"
#url = "https://finance.yahoo.com/news/crowdstrike-reports-second-quarter-fiscal-200500508.html"
#url = "https://finance.yahoo.com/news/stitch-fix-announces-fourth-quarter-200500527.html"
#url = "https://finance.yahoo.com/news/aurora-cannabis-announces-fiscal-2021-201500038.html"
#url = "https://finance.yahoo.com/news/canopy-growth-reports-first-quarter-110000649.html"
#url = "https://finance.yahoo.com/news/nike-inc-reports-fiscal-2022-201500472.html"
#url = "https://finance.yahoo.com/news/prospect-capital-announces-june-2021-230600417.html"
#url = "https://finance.yahoo.com/news/fiverr-announces-second-quarter-2021-050000560.html"
#url = "https://finance.yahoo.com/news/trade-desk-reports-second-quarter-123000360.html"
#url = "https://finance.yahoo.com/news/zoom-reports-financial-results-second-200500829.html"
url = "https://finance.yahoo.com/news/kinsale-capital-group-inc-reports-201000573.html"
source = getPgSource(url)
tables = None
try:
    tables = pd.read_html(source)
except:
    tables = None
print(len(tables))
# Out:
# 8

# %%
tableDesc = getElement("PREVELEM")
print("ALL TABLE DESCRIPTIONS")
print(tableDesc)
tableNum = 1
desc = "NONE"
if tableDesc and tableNum < len(tableDesc):
    desc = tableDesc[tableNum]
print("\nTABLE DESCRIPTION:", desc)

ft = getOneTable(tables, tableNum, desc)
print("\n")
print(ft)
# Out:
# ALL TABLE DESCRIPTIONS
# ['THE COMPANY’S OPERATING RESULTS FOR THE THREE AND SIX MONTHS ENDED JUNE 30, 2021 AND 2020 ARE SUMMARIZED AS FOLLOWS:', 'THE FOLLOWING TABLES SUMMARIZE LOSSES INCURRED FOR THE CURRENT ACCIDENT YEAR AND THE DEVELOPMENT OF PRIOR ACCIDENT YEARS FOR THE THREE AND SIX MONTHS ENDED JUNE 30, 2021 AND 2020:', '<BR/>', 'FOR THE THREE AND SIX MONTHS ENDED JUNE 30, 2021 AND 2020, NET INCOME AND DILUTED EARNINGS PER SHARE RECONCILE TO NET OPERATING EARNINGS AND DILUTED OPERATING EARNINGS PER SHARE AS FOLLOWS:', 'FOR THE THREE AND SIX MONTHS ENDED JUNE 30, 2021 AND 2020, NET INCOME RECONCILES TO UNDERWRITING INCOME AS FOLLOWS:', 'IR@KINSALECAPITALGROUP.COM', '<BR/>']
#
# TABLE DESCRIPTION: THE FOLLOWING TABLES SUMMARIZE LOSSES INCURRED FOR THE CURRENT ACCIDENT YEAR AND THE DEVELOPMENT OF PRIOR ACCIDENT YEARS FOR THE THREE AND SIX MONTHS ENDED JUNE 30, 2021 AND 2020:
# ORIGINAL TABLE
#                                            0   \
# 0                                         NaN
# 1                                         NaN
# 2                                 Loss ratio:
# 3                       Current accident year
# 4  Current accident year - catastrophe losses
# 5   Effect of prior accident year development
# 6                                       Total
# 7                                         NaN
#
#                                  1                                 2   \
# 0  Three Months Ended June 30, 2021  Three Months Ended June 30, 2021
# 1  Losses andLossAdjustmentExpenses  Losses andLossAdjustmentExpenses
# 2                  ($ in thousands)                  ($ in thousands)
# 3                                 $                             85416
# 4                              2834                              2834
# 5                            (9,135                            (9,135
# 6                                 $                             79115
# 7                               NaN                               NaN
#
#                                  3                                 4   \
# 0  Three Months Ended June 30, 2021  Three Months Ended June 30, 2021
# 1  Losses andLossAdjustmentExpenses  Losses andLossAdjustmentExpenses
# 2                  ($ in thousands)                  ($ in thousands)
# 3                               NaN                               NaN
# 4                               NaN                               NaN
# 5                                 )                               NaN
# 6                               NaN                               NaN
# 7                               NaN                               NaN
#
#                                  5                                 6   \
# 0  Three Months Ended June 30, 2021  Three Months Ended June 30, 2021
# 1                               NaN               % of EarnedPremiums
# 2                  ($ in thousands)                  ($ in thousands)
# 3                               NaN                              62.0
# 4                               NaN                               2.1
# 5                               NaN                              (6.6
# 6                               NaN                              57.5
# 7                               NaN                               NaN
#
#                                  7                                 8   \
# 0  Three Months Ended June 30, 2021  Three Months Ended June 30, 2021
# 1               % of EarnedPremiums               % of EarnedPremiums
# 2                  ($ in thousands)                  ($ in thousands)
# 3                               NaN                                 %
# 4                               NaN                                 %
# 5                                 )                                 %
# 6                               NaN                                 %
# 7                               NaN                               NaN
#
#                  9                                 10  \
# 0               NaN  Three Months Ended June 30, 2020
# 1               NaN  Losses andLossAdjustmentExpenses
# 2  ($ in thousands)                  ($ in thousands)
# 3               NaN                                 $
# 4               NaN                               390
# 5               NaN                            (3,616
# 6               NaN                                 $
# 7               NaN                               NaN
#
#                                  11                                12  \
# 0  Three Months Ended June 30, 2020  Three Months Ended June 30, 2020
# 1  Losses andLossAdjustmentExpenses  Losses andLossAdjustmentExpenses
# 2                  ($ in thousands)                  ($ in thousands)
# 3                             61530                               NaN
# 4                               390                               NaN
# 5                            (3,616                                 )
# 6                             58304                               NaN
# 7                               NaN                               NaN
#
#                                  13                                14  \
# 0  Three Months Ended June 30, 2020  Three Months Ended June 30, 2020
# 1  Losses andLossAdjustmentExpenses                               NaN
# 2                  ($ in thousands)                  ($ in thousands)
# 3                               NaN                               NaN
# 4                               NaN                               NaN
# 5                               NaN                               NaN
# 6                               NaN                               NaN
# 7                               NaN                               NaN
#
#                                  15                                16  \
# 0  Three Months Ended June 30, 2020  Three Months Ended June 30, 2020
# 1               % of EarnedPremiums               % of EarnedPremiums
# 2                  ($ in thousands)                  ($ in thousands)
# 3                              63.4                               NaN
# 4                               0.4                               NaN
# 5                              (3.7                                 )
# 6                              60.1                               NaN
# 7                               NaN                               NaN
#
#                                  17
# 0  Three Months Ended June 30, 2020
# 1               % of EarnedPremiums
# 2                  ($ in thousands)
# 3                                 %
# 4                                 %
# 5                                 %
# 6                                 %
# 7                               NaN
# TABLE AFTER REMOVING DUPLICATE ROWS AND COLUMNS
#                                            0   \
# 0                                         NaN
# 1                                         NaN
# 2                                 Loss ratio:
# 3                       Current accident year
# 4  Current accident year - catastrophe losses
# 5   Effect of prior accident year development
# 6                                       Total
#
#                                  1                                 2   \
# 0  Three Months Ended June 30, 2021  Three Months Ended June 30, 2021
# 1  Losses andLossAdjustmentExpenses  Losses andLossAdjustmentExpenses
# 2                  ($ in thousands)                  ($ in thousands)
# 3                                 $                             85416
# 4                              2834                              2834
# 5                            (9,135                            (9,135
# 6                                 $                             79115
#
#                                  3                                 4   \
# 0  Three Months Ended June 30, 2021  Three Months Ended June 30, 2021
# 1  Losses andLossAdjustmentExpenses  Losses andLossAdjustmentExpenses
# 2                  ($ in thousands)                  ($ in thousands)
# 3                               NaN                               NaN
# 4                               NaN                               NaN
# 5                                 )                               NaN
# 6                               NaN                               NaN
#
#                                  5                                 6   \
# 0  Three Months Ended June 30, 2021  Three Months Ended June 30, 2021
# 1                               NaN               % of EarnedPremiums
# 2                  ($ in thousands)                  ($ in thousands)
# 3                               NaN                              62.0
# 4                               NaN                               2.1
# 5                               NaN                              (6.6
# 6                               NaN                              57.5
#
#                                  7                                 8   \
# 0  Three Months Ended June 30, 2021  Three Months Ended June 30, 2021
# 1               % of EarnedPremiums               % of EarnedPremiums
# 2                  ($ in thousands)                  ($ in thousands)
# 3                               NaN                                 %
# 4                               NaN                                 %
# 5                                 )                                 %
# 6                               NaN                                 %
#
#                  9                                 10  \
# 0               NaN  Three Months Ended June 30, 2020
# 1               NaN  Losses andLossAdjustmentExpenses
# 2  ($ in thousands)                  ($ in thousands)
# 3               NaN                                 $
# 4               NaN                               390
# 5               NaN                            (3,616
# 6               NaN                                 $
#
#                                  11                                12  \
# 0  Three Months Ended June 30, 2020  Three Months Ended June 30, 2020
# 1  Losses andLossAdjustmentExpenses  Losses andLossAdjustmentExpenses
# 2                  ($ in thousands)                  ($ in thousands)
# 3                             61530                               NaN
# 4                               390                               NaN
# 5                            (3,616                                 )
# 6                             58304                               NaN
#
#                                  13                                14  \
# 0  Three Months Ended June 30, 2020  Three Months Ended June 30, 2020
# 1  Losses andLossAdjustmentExpenses                               NaN
# 2                  ($ in thousands)                  ($ in thousands)
# 3                               NaN                               NaN
# 4                               NaN                               NaN
# 5                               NaN                               NaN
# 6                               NaN                               NaN
#
#                                  15                                16  \
# 0  Three Months Ended June 30, 2020  Three Months Ended June 30, 2020
# 1               % of EarnedPremiums               % of EarnedPremiums
# 2                  ($ in thousands)                  ($ in thousands)
# 3                              63.4                               NaN
# 4                               0.4                               NaN
# 5                              (3.7                                 )
# 6                              60.1                               NaN
#
#                                  17
# 0  Three Months Ended June 30, 2020
# 1               % of EarnedPremiums
# 2                  ($ in thousands)
# 3                                 %
# 4                                 %
# 5                                 %
# 6                                 %
# HEADER CENTER 0 1
# HEADER BOUNDARY 0 1
# ['0:1']
# TABLE AFTER REMOVING DUPLICATES
#                                            0   \
# 0                                         NaN
# 1                                         NaN
# 2                                 Loss ratio:
# 3                       Current accident year
# 4  Current accident year - catastrophe losses
# 5   Effect of prior accident year development
# 6                                       Total
#
#                                  1                                 2   \
# 0  Three Months Ended June 30, 2021  Three Months Ended June 30, 2021
# 1  Losses andLossAdjustmentExpenses  Losses andLossAdjustmentExpenses
# 2                  ($ in thousands)                  ($ in thousands)
# 3                                 $                             85416
# 4                              2834                              2834
# 5                            (9,135                            (9,135
# 6                                 $                             79115
#
#                                  3                                 4   \
# 0  Three Months Ended June 30, 2021  Three Months Ended June 30, 2021
# 1  Losses andLossAdjustmentExpenses  Losses andLossAdjustmentExpenses
# 2                  ($ in thousands)                  ($ in thousands)
# 3                               NaN                               NaN
# 4                               NaN                               NaN
# 5                                 )                               NaN
# 6                               NaN                               NaN
#
#                                  5                                 6   \
# 0  Three Months Ended June 30, 2021  Three Months Ended June 30, 2021
# 1                               NaN               % of EarnedPremiums
# 2                  ($ in thousands)                  ($ in thousands)
# 3                               NaN                              62.0
# 4                               NaN                               2.1
# 5                               NaN                              (6.6
# 6                               NaN                              57.5
#
#                                  7                                 8   \
# 0  Three Months Ended June 30, 2021  Three Months Ended June 30, 2021
# 1               % of EarnedPremiums               % of EarnedPremiums
# 2                  ($ in thousands)                  ($ in thousands)
# 3                               NaN                                 %
# 4                               NaN                                 %
# 5                                 )                                 %
# 6                               NaN                                 %
#
#                  9                                 10  \
# 0               NaN  Three Months Ended June 30, 2020
# 1               NaN  Losses andLossAdjustmentExpenses
# 2  ($ in thousands)                  ($ in thousands)
# 3               NaN                                 $
# 4               NaN                               390
# 5               NaN                            (3,616
# 6               NaN                                 $
#
#                                  11                                12  \
# 0  Three Months Ended June 30, 2020  Three Months Ended June 30, 2020
# 1  Losses andLossAdjustmentExpenses  Losses andLossAdjustmentExpenses
# 2                  ($ in thousands)                  ($ in thousands)
# 3                             61530                               NaN
# 4                               390                               NaN
# 5                            (3,616                                 )
# 6                             58304                               NaN
#
#                                  13                                14  \
# 0  Three Months Ended June 30, 2020  Three Months Ended June 30, 2020
# 1  Losses andLossAdjustmentExpenses                               NaN
# 2                  ($ in thousands)                  ($ in thousands)
# 3                               NaN                               NaN
# 4                               NaN                               NaN
# 5                               NaN                               NaN
# 6                               NaN                               NaN
#
#                                  15                                16  \
# 0  Three Months Ended June 30, 2020  Three Months Ended June 30, 2020
# 1               % of EarnedPremiums               % of EarnedPremiums
# 2                  ($ in thousands)                  ($ in thousands)
# 3                              63.4                               NaN
# 4                               0.4                               NaN
# 5                              (3.7                                 )
# 6                              60.1                               NaN
#
#                                  17
# 0  Three Months Ended June 30, 2020
# 1               % of EarnedPremiums
# 2                  ($ in thousands)
# 3                                 %
# 4                                 %
# 5                                 %
# 6                                 %
#
# HEADER START 0 HEADER END 1 REPORT END 7
#
# HEADER 1
#     0                                 1                                 2   \
# 0  NaN  Three Months Ended June 30, 2021  Three Months Ended June 30, 2021
# 1  NaN  Losses andLossAdjustmentExpenses  Losses andLossAdjustmentExpenses
#
#                                  3                                 4   \
# 0  Three Months Ended June 30, 2021  Three Months Ended June 30, 2021
# 1  Losses andLossAdjustmentExpenses  Losses andLossAdjustmentExpenses
#
#                                  5                                 6   \
# 0  Three Months Ended June 30, 2021  Three Months Ended June 30, 2021
# 1                               NaN               % of EarnedPremiums
#
#                                  7                                 8    9   \
# 0  Three Months Ended June 30, 2021  Three Months Ended June 30, 2021  NaN
# 1               % of EarnedPremiums               % of EarnedPremiums  NaN
#
#                                  10                                11  \
# 0  Three Months Ended June 30, 2020  Three Months Ended June 30, 2020
# 1  Losses andLossAdjustmentExpenses  Losses andLossAdjustmentExpenses
#
#                                  12                                13  \
# 0  Three Months Ended June 30, 2020  Three Months Ended June 30, 2020
# 1  Losses andLossAdjustmentExpenses  Losses andLossAdjustmentExpenses
#
#                                  14                                15  \
# 0  Three Months Ended June 30, 2020  Three Months Ended June 30, 2020
# 1                               NaN               % of EarnedPremiums
#
#                                  16                                17
# 0  Three Months Ended June 30, 2020  Three Months Ended June 30, 2020
# 1               % of EarnedPremiums               % of EarnedPremiums
#
# REPORT 1
#                                            0                 1   \
# 2                                 Loss ratio:  ($ in thousands)
# 3                       Current accident year                 $
# 4  Current accident year - catastrophe losses              2834
# 5   Effect of prior accident year development            (9,135
# 6                                       Total                 $
#
#                  2                 3                 4                 5   \
# 2  ($ in thousands)  ($ in thousands)  ($ in thousands)  ($ in thousands)
# 3             85416               NaN               NaN               NaN
# 4              2834               NaN               NaN               NaN
# 5            (9,135                 )               NaN               NaN
# 6             79115               NaN               NaN               NaN
#
#                  6                 7                 8                 9   \
# 2  ($ in thousands)  ($ in thousands)  ($ in thousands)  ($ in thousands)
# 3              62.0               NaN                 %               NaN
# 4               2.1               NaN                 %               NaN
# 5              (6.6                 )                 %               NaN
# 6              57.5               NaN                 %               NaN
#
#                  10                11                12                13  \
# 2  ($ in thousands)  ($ in thousands)  ($ in thousands)  ($ in thousands)
# 3                 $             61530               NaN               NaN
# 4               390               390               NaN               NaN
# 5            (3,616            (3,616                 )               NaN
# 6                 $             58304               NaN               NaN
#
#                  14                15                16                17
# 2  ($ in thousands)  ($ in thousands)  ($ in thousands)  ($ in thousands)
# 3               NaN              63.4               NaN                 %
# 4               NaN               0.4               NaN                 %
# 5               NaN              (3.7                 )                 %
# 6               NaN              60.1               NaN                 %
# SPECIAL COLUMNS NEED TO BE PRESERVED
# Int64Index([1, 10], dtype='int64')
# DUPLICATE HEADER COLUMNS TO BE DELETED
# {1: [2, 3, 4], 6: [7, 7], 10: [11, 12, 13], 15: [16, 16]}
#
# AFTER DELETING DUPLICATE COLUMN HEADER
#
# HEADER 1
#     0                                 1                                 5   \
# 0  NaN  Three Months Ended June 30, 2021  Three Months Ended June 30, 2021
# 1  NaN  Losses andLossAdjustmentExpenses                               NaN
#
#                                  6                                 8    9   \
# 0  Three Months Ended June 30, 2021  Three Months Ended June 30, 2021  NaN
# 1               % of EarnedPremiums               % of EarnedPremiums  NaN
#
#                                  10                                14  \
# 0  Three Months Ended June 30, 2020  Three Months Ended June 30, 2020
# 1  Losses andLossAdjustmentExpenses                               NaN
#
#                                  15                                17
# 0  Three Months Ended June 30, 2020  Three Months Ended June 30, 2020
# 1               % of EarnedPremiums               % of EarnedPremiums
# HEADER BATCH 1
# 0    NaN
# 1    NaN
# Name: 0, dtype: object
#
# INVALID HEADER
# []
# HEADER BATCH 2
#                                  1                                 5   \
# 0  Three Months Ended June 30, 2021  Three Months Ended June 30, 2021
# 1  Losses andLossAdjustmentExpenses                               NaN
#
#                                  6                                 8   \
# 0  Three Months Ended June 30, 2021  Three Months Ended June 30, 2021
# 1               % of EarnedPremiums               % of EarnedPremiums
#
#                                  10                                14  \
# 0  Three Months Ended June 30, 2020  Three Months Ended June 30, 2020
# 1  Losses andLossAdjustmentExpenses                               NaN
#
#                                  15                                17
# 0  Three Months Ended June 30, 2020  Three Months Ended June 30, 2020
# 1               % of EarnedPremiums               % of EarnedPremiums
# FINAL HEADER
#     0                                 1                                 5   \
# 0  nan  Three Months Ended June 30, 2021  Three Months Ended June 30, 2021
# 1  nan  Losses andLossAdjustmentExpenses                               nan
#
#                                  6                                 8   \
# 0  Three Months Ended June 30, 2021  Three Months Ended June 30, 2021
# 1               % of EarnedPremiums               % of EarnedPremiums
#
#                                  10                                14  \
# 0  Three Months Ended June 30, 2020  Three Months Ended June 30, 2020
# 1  Losses andLossAdjustmentExpenses                               nan
#
#                                  15                                17
# 0  Three Months Ended June 30, 2020  Three Months Ended June 30, 2020
# 1               % of EarnedPremiums               % of EarnedPremiums
#
# AFTER DELETING DUPLICATE ROWS
#
# REPORT 1
#                                            0                 1   \
# 2                                 Loss ratio:  ($ in thousands)
# 3                       Current accident year                 $
# 4  Current accident year - catastrophe losses              2834
# 5   Effect of prior accident year development            (9,135
# 6                                       Total                 $
#
#                  2                 3                 4                 5   \
# 2  ($ in thousands)  ($ in thousands)  ($ in thousands)  ($ in thousands)
# 3             85416               NaN               NaN               NaN
# 4              2834               NaN               NaN               NaN
# 5            (9,135                 )               NaN               NaN
# 6             79115               NaN               NaN               NaN
#
#                  6                 7                 8                 9   \
# 2  ($ in thousands)  ($ in thousands)  ($ in thousands)  ($ in thousands)
# 3              62.0               NaN                 %               NaN
# 4               2.1               NaN                 %               NaN
# 5              (6.6                 )                 %               NaN
# 6              57.5               NaN                 %               NaN
#
#                  10                11                12                13  \
# 2  ($ in thousands)  ($ in thousands)  ($ in thousands)  ($ in thousands)
# 3                 $             61530               NaN               NaN
# 4               390               390               NaN               NaN
# 5            (3,616            (3,616                 )               NaN
# 6                 $             58304               NaN               NaN
#
#                  14                15                16                17
# 2  ($ in thousands)  ($ in thousands)  ($ in thousands)  ($ in thousands)
# 3               NaN              63.4               NaN                 %
# 4               NaN               0.4               NaN                 %
# 5               NaN              (3.7                 )                 %
# 6               NaN              60.1               NaN                 %
#
# SPECIAL COLUMNS
# Int64Index([1, 10], dtype='int64')
#
# REPORT AFTER MERGING SPECIAL COLUMNS
#                                            0                1   \
# 2                                  LOSS RATIO  -$ in thousands
# 3                       CURRENT ACCIDENT YEAR           $85416
# 4  CURRENT ACCIDENT YEAR - CATASTROPHE LOSSES             2834
# 5   EFFECT OF PRIOR ACCIDENT YEAR DEVELOPMENT            -9135
# 6                                       TOTAL           $79115
#
#                 3                4                5                6   \
# 2  -$ in thousands  -$ in thousands  -$ in thousands  -$ in thousands
# 3              nan              nan              nan            62.0%
# 4              nan              nan              nan             2.1%
# 5                               nan              nan            -6.6%
# 6              nan              nan              nan            57.5%
#
#                 7                9                10               12  \
# 2  -$ in thousands  -$ in thousands  -$ in thousands  -$ in thousands
# 3              nan              nan           $61530              nan
# 4              nan              nan              390              nan
# 5                               nan            -3616
# 6              nan              nan           $58304              nan
#
#                 13               14               15               16
# 2  -$ in thousands  -$ in thousands  -$ in thousands  -$ in thousands
# 3              nan              nan            63.4%              nan
# 4              nan              nan             0.4%              nan
# 5              nan              nan            -3.7%
# 6              nan              nan            60.1%              nan
#
# HEADER COLUMNS Int64Index([0, 1, 5, 6, 8, 10, 14, 15, 17], dtype='int64')
# REPORT COLUMNS Int64Index([0, 1, 3, 4, 5, 6, 7, 9, 10, 12, 13, 14, 15, 16], dtype='int64')
# INTERSECTION COLUMNS Int64Index([0, 1, 5, 6, 10, 14, 15], dtype='int64')
# FINAL HEADER
#     0                                 1                                 5   \
# 0  nan  Three Months Ended June 30, 2021  Three Months Ended June 30, 2021
# 1  nan  Losses andLossAdjustmentExpenses                               nan
#
#                                  6                                 10  \
# 0  Three Months Ended June 30, 2021  Three Months Ended June 30, 2020
# 1               % of EarnedPremiums  Losses andLossAdjustmentExpenses
#
#                                  14                                15
# 0  Three Months Ended June 30, 2020  Three Months Ended June 30, 2020
# 1                               nan               % of EarnedPremiums
#
# ORIGINAL FIRST COLUMN NAME
# NAN
#
# TABLE DESCRIPTION
# THE FOLLOWING TABLES SUMMARIZE LOSSES INCURRED FOR THE CURRENT ACCIDENT YEAR AND THE DEVELOPMENT OF PRIOR ACCIDENT YEARS FOR THE THREE AND SIX MONTHS ENDED JUNE 30, 2021 AND 2020:
#
# FINAL HEADER STRING
# ['METRIC', 'THREE MONTHS ENDED JUNE 30, 2021 LOSSES ANDLOSSADJUSTMENTEXPENSES', 'THREE MONTHS ENDED JUNE 30, 2021', 'THREE MONTHS ENDED JUNE 30, 2021 % OF EARNEDPREMIUMS', 'THREE MONTHS ENDED JUNE 30, 2020 LOSSES ANDLOSSADJUSTMENTEXPENSES', 'THREE MONTHS ENDED JUNE 30, 2020', 'THREE MONTHS ENDED JUNE 30, 2020 % OF EARNEDPREMIUMS']
#
# FINAL REPORT
#                                        METRIC  \
# 2                                  LOSS RATIO
# 3                       CURRENT ACCIDENT YEAR
# 4  CURRENT ACCIDENT YEAR - CATASTROPHE LOSSES
# 5   EFFECT OF PRIOR ACCIDENT YEAR DEVELOPMENT
# 6                                       TOTAL
#
#   THREE MONTHS ENDED JUNE 30, 2021 LOSSES ANDLOSSADJUSTMENTEXPENSES  \
# 2                                    -$ in thousands
# 3                                             $85416
# 4                                               2834
# 5                                              -9135
# 6                                             $79115
#
#   THREE MONTHS ENDED JUNE 30, 2021  \
# 2                  -$ in thousands
# 3                              nan
# 4                              nan
# 5                              nan
# 6                              nan
#
#   THREE MONTHS ENDED JUNE 30, 2021 % OF EARNEDPREMIUMS  \
# 2                                    -$ in thousands
# 3                                              62.0%
# 4                                               2.1%
# 5                                              -6.6%
# 6                                              57.5%
#
#   THREE MONTHS ENDED JUNE 30, 2020 LOSSES ANDLOSSADJUSTMENTEXPENSES  \
# 2                                    -$ in thousands
# 3                                             $61530
# 4                                                390
# 5                                              -3616
# 6                                             $58304
#
#   THREE MONTHS ENDED JUNE 30, 2020  \
# 2                  -$ in thousands
# 3                              nan
# 4                              nan
# 5                              nan
# 6                              nan
#
#   THREE MONTHS ENDED JUNE 30, 2020 % OF EARNEDPREMIUMS
# 2                                    -$ in thousands
# 3                                              63.4%
# 4                                               0.4%
# 5                                              -3.7%
# 6                                              60.1%
#
#
# {'1:T:OPMETRIC:1': '[{"METRIC":"LOSS RATIO","THREE MONTHS ENDED JUNE 30, 2021 LOSSES ANDLOSSADJUSTMENTEXPENSES":"-$ in thousands","THREE MONTHS ENDED JUNE 30, 2021":"-$ in thousands","THREE MONTHS ENDED JUNE 30, 2021 % OF EARNEDPREMIUMS":"-$ in thousands","THREE MONTHS ENDED JUNE 30, 2020 LOSSES ANDLOSSADJUSTMENTEXPENSES":"-$ in thousands","THREE MONTHS ENDED JUNE 30, 2020":"-$ in thousands","THREE MONTHS ENDED JUNE 30, 2020 % OF EARNEDPREMIUMS":"-$ in thousands"},{"METRIC":"CURRENT ACCIDENT YEAR","THREE MONTHS ENDED JUNE 30, 2021 LOSSES ANDLOSSADJUSTMENTEXPENSES":"$85416","THREE MONTHS ENDED JUNE 30, 2021":"nan","THREE MONTHS ENDED JUNE 30, 2021 % OF EARNEDPREMIUMS":"62.0%","THREE MONTHS ENDED JUNE 30, 2020 LOSSES ANDLOSSADJUSTMENTEXPENSES":"$61530","THREE MONTHS ENDED JUNE 30, 2020":"nan","THREE MONTHS ENDED JUNE 30, 2020 % OF EARNEDPREMIUMS":"63.4%"},{"METRIC":"CURRENT ACCIDENT YEAR - CATASTROPHE LOSSES","THREE MONTHS ENDED JUNE 30, 2021 LOSSES ANDLOSSADJUSTMENTEXPENSES":"2834","THREE MONTHS ENDED JUNE 30, 2021":"nan","THREE MONTHS ENDED JUNE 30, 2021 % OF EARNEDPREMIUMS":"2.1%","THREE MONTHS ENDED JUNE 30, 2020 LOSSES ANDLOSSADJUSTMENTEXPENSES":"390","THREE MONTHS ENDED JUNE 30, 2020":"nan","THREE MONTHS ENDED JUNE 30, 2020 % OF EARNEDPREMIUMS":"0.4%"},{"METRIC":"EFFECT OF PRIOR ACCIDENT YEAR DEVELOPMENT","THREE MONTHS ENDED JUNE 30, 2021 LOSSES ANDLOSSADJUSTMENTEXPENSES":"-9135","THREE MONTHS ENDED JUNE 30, 2021":"nan","THREE MONTHS ENDED JUNE 30, 2021 % OF EARNEDPREMIUMS":"-6.6%","THREE MONTHS ENDED JUNE 30, 2020 LOSSES ANDLOSSADJUSTMENTEXPENSES":"-3616","THREE MONTHS ENDED JUNE 30, 2020":"nan","THREE MONTHS ENDED JUNE 30, 2020 % OF EARNEDPREMIUMS":"-3.7%"},{"METRIC":"TOTAL","THREE MONTHS ENDED JUNE 30, 2021 LOSSES ANDLOSSADJUSTMENTEXPENSES":"$79115","THREE MONTHS ENDED JUNE 30, 2021":"nan","THREE MONTHS ENDED JUNE 30, 2021 % OF EARNEDPREMIUMS":"57.5%","THREE MONTHS ENDED JUNE 30, 2020 LOSSES ANDLOSSADJUSTMENTEXPENSES":"$58304","THREE MONTHS ENDED JUNE 30, 2020":"nan","THREE MONTHS ENDED JUNE 30, 2020 % OF EARNEDPREMIUMS":"60.1%"}]'}
